# %% [markdown]
# IMPORTANT: Make sure to run this notebook first (Create Mapping File from Echonest Mapping Project) in order to create 'mapping.csv' (if not already available)
#
# Import the Dataset and have an initial exploration, see shifts and possible issues.

# %%
import h5py
import numpy as np
import pandas as pd
from glob import glob, iglob
import json

# %%
# %cd ../data/raw/
# %ls
# Out:
# [Errno 2] No such file or directory: '../data/raw/'
# /Users/sebastian/git_repos/data_science/hit_predictor/data/raw
# MillionSongFullSummary/ faq/

# %% [markdown]
# First we'll look at the summary file

# %%
data = h5py.File('MillionSongFullSummary/msd_summary_file.h5','r')
for key in data.keys():
    print(key)
# Out:
# analysis
# metadata
# musicbrainz

# %%
# Load Metadata
meta_data_songs = pd.DataFrame(data['metadata']['songs'].value)
meta_data_songs.head()
# Out:
#   analyzer_version  artist_7digitalid  artist_familiarity  artist_hotttnesss  \
# 0              b''               4069            0.649822           0.394032
# 1              b''             113480            0.439604           0.356992
# 2              b''              63531            0.643681           0.437504
# 3              b''              65051            0.448501           0.372349
# 4              b''             158279            0.000000           0.000000
#
#                artist_id  artist_latitude       artist_location  \
# 0  b'ARYZTJS1187B98C555'              NaN                   b''
# 1  b'ARMVN3U1187FB3A1EB'              NaN                   b''
# 2  b'ARGEKB01187FB50750'          55.8578  b'Glasgow, Scotland'
# 3  b'ARNWYLR1187B9B2F9C'              NaN                   b''
# 4  b'AREQDTE1269FB37231'              NaN                   b''
#
#    artist_longitude                              artist_mbid  \
# 0               NaN  b'357ff05d-848a-44cf-b608-cb34b5701ae5'
# 1               NaN  b'8d7ef530-a6fd-4f8f-b2e2-74aec765e0f9'
# 2          -4.24251  b'3d403d44-36ce-465c-ad43-ae877e65adc4'
# 3               NaN  b'12be7648-7094-495f-90e6-df4189d68615'
# 4               NaN                                      b''
#
#            artist_name  artist_playmeid genre  idx_artist_terms  \
# 0  b'Faster Pussy cat'            44895   b''                 0
# 1  b'Karkkiautomaatti'               -1   b''                 0
# 2    b'Hudson Mohawke'               -1   b''                 0
# 3       b'Yerba Brava'            34000   b''                 0
# 4        b'Der Mystic'               -1   b''                 0
#
#    idx_similar_artists                                  release  \
# 0                    0                 b'Monster Ballads X-Mas'
# 1                    0                    b'Karkuteill\xc3\xa4'
# 2                    0                                b'Butter'
# 3                    0                               b'De Culo'
# 4                    0  b'Rene Ablaze Presents Winter Sessions'
#
#    release_7digitalid  song_hotttnesss                song_id  \
# 0              633681         0.542899  b'SOQMMHC12AB0180CB8'
# 1              145266         0.299877  b'SOVFVAK12A8C1350D9'
# 2              625706         0.617871  b'SOGTUKN12AB017F4F1'
# 3              199368              NaN  b'SOBNYVR12A8C13558C'
# 4              209038              NaN  b'SOHSBXH12A8C13B0DF'
#
#                      title  track_7digitalid
# 0          b'Silent Night'           7032331
# 1           b'Tanssi vaan'           1514808
# 2     b'No One Could Ever'           6945353
# 3  b'Si Vos Quer\xc3\xa9s'           2168257
# 4      b'Tangle Of Aspens'           2264873

# %%
meta_reduced = meta_data_songs.loc[:,['artist_name','artist_mbid','title','song_id']].copy()

# %%
# Transform bytes to strings
byte_str_columns = ['artist_mbid','artist_name','song_id','title']
for col in byte_str_columns:    
    meta_reduced.loc[~meta_reduced[col].isnull(),col] = meta_reduced.loc[~meta_reduced[col].isnull(),col].str.decode('utf-8')
    meta_reduced.loc[meta_reduced[col] == '',col] = np.nan
    
# Test output
meta_reduced.head()
# Out:
#         artist_name                           artist_mbid              title  \
# 0  Faster Pussy cat  357ff05d-848a-44cf-b608-cb34b5701ae5       Silent Night
# 1  Karkkiautomaatti  8d7ef530-a6fd-4f8f-b2e2-74aec765e0f9        Tanssi vaan
# 2    Hudson Mohawke  3d403d44-36ce-465c-ad43-ae877e65adc4  No One Could Ever
# 3       Yerba Brava  12be7648-7094-495f-90e6-df4189d68615      Si Vos Querés
# 4        Der Mystic                                   NaN   Tangle Of Aspens
#
#               song_id
# 0  SOQMMHC12AB0180CB8
# 1  SOVFVAK12A8C1350D9
# 2  SOGTUKN12AB017F4F1
# 3  SOBNYVR12A8C13558C
# 4  SOHSBXH12A8C13B0DF

# %%
# Import mapping.csv file (see notebook Create Mapping File from Echonest Mapping Project)
mapping_catalog_view = pd.read_csv('../interim/mapping_summary.csv',sep='\t').drop_duplicates(subset=['id','tracks.catalog'],keep='first')
mapping_catalog_view.head()
# Out:
#   tracks.catalog                                  tracks.foreign_id  \
# 0        spotify               spotify:track:4UvblPNa9nwMTkzLtUBxnj
# 1    musicbrainz  musicbrainz:track:73ac9287-2056-4ec8-b5f2-5189...
# 2        spotify               spotify:track:2biysHaswSmcpAM1T554BR
# 4    musicbrainz  musicbrainz:track:00f26e00-4907-4869-91e6-9e5c...
# 5        spotify               spotify:track:4YkMlmjR7KVwbZa3D3ek8N
#
#             tracks.id      artist_name                  id  \
# 0  TRNAQME144D1525B11  Jackson Sisters  SOCSZMF12AAF3B3498
# 1  TRXBBYC13B7C4E2FC5  Jackson Sisters  SOCSZMF12AAF3B3498
# 2  TROAEGA144D0FE9F1A          Journey  SOCSMOE12A8C1459E8
# 4  TREIEXB13B7B543E25          Journey  SOCSMOE12A8C1459E8
# 5  TRYQDDR144D154494E   Chamillionaire  SOCBVBO1315CD46DFA
#
#                        title
# 0  Why Do Fools Fall In Love
# 1  Why Do Fools Fall In Love
# 2           Live and Breathe
# 4           Live and Breathe
# 5            Think I'm Crazy

# %%
ids_pivot_df = mapping_catalog_view.pivot(index='id',columns='tracks.catalog',values='tracks.foreign_id').reset_index()
ids_pivot_df.head()
# Out:
# tracks.catalog                  id  \
# 0               SOAAAAI1313438F93F
# 1               SOAAAAI13134396D63
# 2               SOAAABI12A8C13615F
# 3               SOAAABJ12A58A7A848
# 4               SOAAABL131712CF706
#
# tracks.catalog                                        musicbrainz  \
# 0                                                             NaN
# 1               musicbrainz:track:2ee83483-687e-4fef-90d5-3cb6...
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# tracks.catalog                               spotify
# 0               spotify:track:4rmDmhbsQCnotwzoBwIEDY
# 1               spotify:track:4XfqVEMwPUMHPB96CXcxbU
# 2               spotify:track:6i9aLGfG1Id1oCcpgmRjmE
# 3               spotify:track:5wvw53vrVv7dbEGQalRZtO
# 4               spotify:track:1GkGoUh9pa99J1RYNCLxkk

# %%
unique_songs_df = mapping_catalog_view.drop_duplicates(subset='id',keep='first')
mapping_df = unique_songs_df.merge(ids_pivot_df,how='left',on='id').loc[:,['id','tracks.id','artist_name','title','musicbrainz','spotify']]
mapping_df.head()
# Out:
#                    id           tracks.id       artist_name  \
# 0  SOCSZMF12AAF3B3498  TRNAQME144D1525B11   Jackson Sisters
# 1  SOCSMOE12A8C1459E8  TROAEGA144D0FE9F1A           Journey
# 2  SOCBVBO1315CD46DFA  TRYQDDR144D154494E    Chamillionaire
# 3  SOCSZXL12A6D4F8145  TRCSAFR147B6EB3D98         Moonspell
# 4  SOCSBRR12A6D4FBEC2  TRJDLNF144D118CFAF  Oliver Huntemann
#
#                                            title  \
# 0                      Why Do Fools Fall In Love
# 1                               Live and Breathe
# 2                                Think I'm Crazy
# 3                                          Opium
# 4  37 Grad (Arnaud Rebotini's Blackstrobe Remix)
#
#                                          musicbrainz  \
# 0  musicbrainz:track:73ac9287-2056-4ec8-b5f2-5189...
# 1  musicbrainz:track:00f26e00-4907-4869-91e6-9e5c...
# 2  musicbrainz:track:119df7c9-66f2-4a22-9ca7-4fc1...
# 3  musicbrainz:track:041f4e5f-c065-4d22-a858-e64e...
# 4  musicbrainz:track:9a631053-a49d-4d47-a306-b5ea...
#
#                                 spotify
# 0  spotify:track:4UvblPNa9nwMTkzLtUBxnj
# 1  spotify:track:2biysHaswSmcpAM1T554BR
# 2  spotify:track:4YkMlmjR7KVwbZa3D3ek8N
# 3  spotify:track:7oZHYB2HXjvgcMfu8tTqBA
# 4  spotify:track:3CSkXJgKEupR2mYx6CnW8c

# %%
meta_reduced_sp_ids = meta_reduced.merge(mapping_df,left_on=['song_id','artist_name','title'],right_on=['id','artist_name','title'],how='left')
meta_reduced_sp_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1163102 entries, 0 to 1163101
# Data columns (total 8 columns):
# artist_name          1163102 non-null object
# artist_mbid          1099146 non-null object
# title                1163087 non-null object
# song_id              1163102 non-null object
# tracks.catalog       455026 non-null object
# tracks.foreign_id    455026 non-null object
# tracks.id            455026 non-null object
# id                   455026 non-null object
# dtypes: object(8)
# memory usage: 79.9+ MB

# %%
meta_reduced_sp_ids.head()

# %%
# Generate a DataFrame with unique artists that have a musicbrainzid
msd_artists_df = meta_reduced_sp_ids.dropna(subset=['artist_mbid']).drop_duplicates(subset=['artist_name'],keep='first').loc[:,['artist_name','artist_mbid']]
msd_artists_df.head()
# Out:
#         artist_name                           artist_mbid
# 0  Faster Pussy cat  357ff05d-848a-44cf-b608-cb34b5701ae5
# 1  Karkkiautomaatti  8d7ef530-a6fd-4f8f-b2e2-74aec765e0f9
# 2    Hudson Mohawke  3d403d44-36ce-465c-ad43-ae877e65adc4
# 3       Yerba Brava  12be7648-7094-495f-90e6-df4189d68615
# 5  David Montgomery  d087b377-bab7-46c4-bd12-15debebb5d61

# %%
# Generate Artists File
output_dir = '../interim/'
target = 'msd_artists.csv'
msd_artists_df.to_csv(output_dir + target, sep='\t',index=False,encoding='utf-8')
