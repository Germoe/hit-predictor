# %% [markdown]
# Import the Dataset and have an initial exploration, see shifts and possible issues.

# %%
import h5py
import pandas as pd

# %%
# %cd ../data/raw/
# %ls
# Out:
# /Users/sebastian/git_repos/data_science/hit_predictor/data/raw
# MillionSongSubset/

# %% [markdown]
# First we'll look at the summary file

# %%
data = h5py.File('MillionSongFullSummary/msd_summary_file.h5','r')
for key in data.keys():
    print(key)
# Out:
# analysis
# metadata
# musicbrainz

# %%
for key in data['musicbrainz'].keys():
    print(key)
    
analysis_songs = pd.DataFrame(data['analysis']['songs'].value)
analysis_songs.head()
# Out:
# songs
# ['analysis_sample_rate', 'audio_md5', 'danceability', 'duration', 'end_of_fade_in', 'energy', 'idx_bars_confidence', 'idx_bars_start', 'idx_beats_confidence', 'idx_beats_start', 'idx_sections_confidence', 'idx_sections_start', 'idx_segments_confidence', 'idx_segments_loudness_max', 'idx_segments_loudness_max_time', 'idx_segments_loudness_start', 'idx_segments_pitches', 'idx_segments_start', 'idx_segments_timbre', 'idx_tatums_confidence', 'idx_tatums_start', 'key', 'key_confidence', 'loudness', 'mode', 'mode_confidence', 'start_of_fade_out', 'tempo', 'time_signature', 'time_signature_confidence', 'track_id']
#    analysis_sample_rate                            audio_md5  danceability  \
# 0                 22050  b'a600d65cf157a306be60f26ecbf218f4'           0.0
# 1                 22050  b'c64d75b0588e5ab552ee94548b50a4fa'           0.0
# 2                 22050  b'0cadd310865701bb93ced1cd78e8910a'           0.0
# ...

# %%
meta_data_songs = pd.DataFrame(data['metadata']['songs'].value)
meta_data_songs.head()
# Out:
#   analyzer_version  artist_7digitalid  artist_familiarity  artist_hotttnesss  \
# 0              b''              29785            0.780462           0.574275
# 1              b''             167867            0.561590           0.420570
# 2              b''               7725            0.687687           0.406686
# 3              b''               2799            0.391741           0.291265
# 4              b''              74269            0.593416           0.395710
#
#                artist_id  artist_latitude  \
# 0  b'ARMQHX71187B9890D3'              NaN
# 1  b'AR2PT4M1187FB55B1A'              NaN
# 2  b'ARDI88R1187B98DAB2'              NaN
# 3  b'ARUKJUP12086C14589'              NaN
# 4  b'ARZEWUR1187FB53DC8'         50.45663
#
#                                    artist_location  artist_longitude  \
# 0                                   b'Atlanta, GA'               NaN
# 1                                              b''               NaN
# ...

# %%
musicbrainz_songs = pd.DataFrame(data['musicbrainz']['songs'].value)
musicbrainz_songs.head()
# Out:
#    idx_artist_mbtags  year
# 0                  0  2001
# 1                  0  1984
# 2                  0     0
# 3                  0     0
# 4                  0  2010

# %%
one_track_data = h5py.File('MillionSongSubset/data/A/A/A/TRAAAAW128F429D538.h5','r')
for key in one_track_data.keys():
    print(key)
# Out:
# analysis
# metadata
# musicbrainz

# %%
one_track = pd.DataFrame(one_track_data['analysis']['songs'].value)
one_track
# Out:
# Index(['analysis_sample_rate', 'audio_md5', 'danceability', 'duration',
#        'end_of_fade_in', 'energy', 'idx_bars_confidence', 'idx_bars_start',
#        'idx_beats_confidence', 'idx_beats_start', 'idx_sections_confidence',
#        'idx_sections_start', 'idx_segments_confidence',
#        'idx_segments_loudness_max', 'idx_segments_loudness_max_time',
#        'idx_segments_loudness_start', 'idx_segments_pitches',
#        'idx_segments_start', 'idx_segments_timbre', 'idx_tatums_confidence',
#        'idx_tatums_start', 'key', 'key_confidence', 'loudness', 'mode',
#        'mode_confidence', 'start_of_fade_out', 'tempo', 'time_signature',
#        'time_signature_confidence', 'track_id'],
#       dtype='object')
# /Users/sebastian/anaconda3/envs/hit_predictor/lib/python3.7/site-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# ...

# %%
sorted(analysis_songs.columns) == sorted(one_track.columns)
# Out:
# True
