# %% [markdown]
# # Wrangling of Hot 100 Data
#
# In this initial step I'll merge the raw data scraped from the [Billboard Hot 100 Charts](https://www.billboard.com/charts/hot-100/) with the songs' respective features from the [Spotify API Features Endpoint](https://developer.spotify.com/documentation/web-api/reference/tracks/get-several-audio-features/).

# %%
import os
import numpy as np
import pandas as pd
from glob import glob
import re
import time
from similarity.metric_lcs import MetricLCS # String Similarity https://github.com/luozhouyang/python-string-similarity
from similarity.ngram import NGram

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

twogram = NGram(2)
metric_lcs = MetricLCS()

# %%
# Switch Directory to ../data/interim/
current_dir = os.getcwd()
destination_dir = '/data/interim'
if current_dir[-len(destination_dir):] != destination_dir:
    os.chdir('..' + destination_dir)
else:
    print('already in correct directory: ',current_dir)
# Out:
# already in correct directory:  /Users/sebastian/git_repos/data_science/hit_predictor/data/interim

# %% [markdown]
# The scraper has separated each chart into a separate file. These need to be merged into one comprehensive Dataframe. Each file contains 100 tracks.

# %%
# Read in all Subfiles
filenames = glob('hot100/*.csv')
print("There is a total of {} files with 100 songs each.".format(len(filenames)))
hot100_dfs = [pd.read_csv(filepath,sep='\t',usecols=['date','rank','title','artist'],
                          parse_dates=['date']) for filepath in filenames]
hot100_all = pd.concat(hot100_dfs)
print("The total number of songs is {}.".format(len(hot100_all)))
hot100_all.head()
# Out:
# There is a total of 3167 files with 100 songs each.
# The total number of songs is 316685.
#    rank       date                                              title  \
# 0     1 1967-07-08                                              Windy
# 1     2 1967-07-08                                 Little Bit O' Soul
# 2     3 1967-07-08                         Can't Take My Eyes Off You
# 3     4 1967-07-08  San Francisco (Be Sure To Wear Flowers In Your...
# 4     5 1967-07-08                          Don't Sleep In The Subway
#
#                 artist
# 0      The Association
# 1  The Music Explosion
# 2        Frankie Valli
# 3       Scott McKenzie
# 4         Petula Clark

# %% [markdown]
# We can see that 3167 files (100 songs each) shows a total of 15 missing songs. We'll look at those 15 songs further down in this analysis.

# %% [markdown]
# Read in the spotify ids (created using `make data` in console) as a DataFrame to match with Hot 100 chart set.

# %%
# Read in all Subfiles
hot100_ids = pd.read_csv('../iterators/unique_songs_hot100_spotify_ids.csv',sep='\t').drop_duplicates(subset=['iterator'],keep='first')

# remove karaoke artists
cond_not_verified = hot100_ids['verified'] == False
cond = cond_not_verified & hot100_ids['spotify_artist'].str.contains('KARAOKE', flags=re.IGNORECASE)
hot100_ids.loc[cond,['iterator','spotify_artist','spotify_title']] = np.nan

# drop NaN values
hot100_ids = hot100_ids.dropna(subset=['iterator'])

print(len(hot100_ids))
hot100_ids.head()
# Out:
# 21839
#                  iterator                                     filename  \
# 1  59IxJQuFPmW4Xvy7GynZDF  ./data/interim/hot100/hot100_1967-07-03.csv
# 2  1cmjxqobVTrgAiJ0btAleN  ./data/interim/hot100/hot100_1967-07-03.csv
# 3  30nBdjVsKGchhjSy89mv2N  ./data/interim/hot100/hot100_1967-07-03.csv
# 4  5eeZr5k6eprE1NToNTZuxs  ./data/interim/hot100/hot100_1967-07-03.csv
# 5  1hh6PfvINPBnKplONjgju4  ./data/interim/hot100/hot100_1967-07-03.csv
#
#                           artist                          title  \
# 1                      Four Tops               7 Rooms Of Gloom
# 2                   Procol Harum         A Whiter Shade Of Pale
# 3    Marvin Gaye & Tammi Terrell  Ain't No Mountain High Enough
# 4                 Dionne Warwick                          Alfie
# 5  Sam The Sham and the Pharaohs                    Black Sheep
#
#                 spotify_artist  \
# 1                    Four Tops
# 2                 Procol Harum
# 3              Various Artists
# 4               Dionne Warwick
# 5  Sam The Sham & The Pharaohs
#
#                                       spotify_title verified
# 1                                  7-Rooms Of Gloom    False
# 2  A Whiter Shade of Pale - Original Single Version    False
# 3                     Ain't No Mountain High Enough    False
# 4                                             Alfie     True
# 5                      Black Sheep - Single Version    False

# %% [markdown]
# Artist Name and Title matching is not straight-forward due to varying spelling and formatting of names and titles. To best match spotify ids with the least possible issues we'll generalize the names and titles as much as possible and use a twogram distance to compare strings in case we can't find an exact match.

# %%
# copy columns of original artist and title for wrangling purposes
hot100_ids['orig_artist'] = hot100_ids.loc[:,'artist']
hot100_ids['orig_title'] = hot100_ids.loc[:,'title']

rel_columns = ['orig_artist','orig_title','spotify_artist','spotify_title']

# Convert all relevant str columns to uppercase
hot100_ids.loc[:,rel_columns] = hot100_ids.loc[:,rel_columns].apply(lambda x: x.str.upper())

# generalize to "and"
pattern = ' & | FEATURING'
target = ' AND '
cond = hot100_ids.orig_artist.str.contains(pattern) | hot100_ids.orig_title.str.contains(pattern) | hot100_ids.spotify_artist.str.contains(pattern) | hot100_ids.spotify_title.str.contains(pattern)
for column in rel_columns:
    hot100_ids.loc[cond,column] = hot100_ids.loc[cond,column].str.replace(pattern,target)
hot100_ids.head()

# generalize '-' to ' '
pattern = '\-|\(|\)|\,|\/|\s+'
target = ' '
cond = hot100_ids.orig_artist.str.contains(pattern) | hot100_ids.orig_title.str.contains(pattern) | hot100_ids.spotify_artist.str.contains(pattern) | hot100_ids.spotify_title.str.contains(pattern)
for column in rel_columns:
    hot100_ids.loc[cond,column] = hot100_ids.loc[cond,column].str.replace(pattern,target)
hot100_ids.head()

# generalize '’' to '\''
pattern = '’|\'|\.'
target = ''
cond = hot100_ids.orig_artist.str.contains(pattern) | hot100_ids.orig_title.str.contains(pattern) | hot100_ids.spotify_artist.str.contains(pattern) | hot100_ids.spotify_title.str.contains(pattern)
for column in rel_columns:
    hot100_ids.loc[cond,column] = hot100_ids.loc[cond,column].str.replace(pattern,target)
hot100_ids.head()

# generalize special characters 'é' to 'e'
pattern = 'É'
target = 'E'
cond = hot100_ids.orig_artist.str.contains(pattern) | hot100_ids.orig_title.str.contains(pattern) | hot100_ids.spotify_artist.str.contains(pattern) | hot100_ids.spotify_title.str.contains(pattern)
for column in rel_columns:
    hot100_ids.loc[cond,column] = hot100_ids.loc[cond,column].str.replace(pattern,target)
hot100_ids.head()

# remove spaces in the front and back
pattern = '^\s|\s$'
target = ''
cond = hot100_ids.orig_artist.str.contains(pattern) | hot100_ids.orig_title.str.contains(pattern) | hot100_ids.spotify_artist.str.contains(pattern) | hot100_ids.spotify_title.str.contains(pattern)
for column in rel_columns:
    hot100_ids.loc[cond,column] = hot100_ids.loc[cond,column].str.replace(pattern,target)
hot100_ids.head()

# verify if case issue
cond = (hot100_ids['orig_artist'].str.lower() == hot100_ids['spotify_artist'].str.lower()) & (hot100_ids['orig_title'].str.lower() == hot100_ids['spotify_title'].str.lower()) 
hot100_ids.loc[cond,'verified'] = True

def twogram_distance(row):
    # only compare string values
    return twogram.distance(row[0],row[1])

hot100_ids['twogram_artist'] = hot100_ids.loc[:,['orig_artist','spotify_artist']].apply(twogram_distance,axis=1)
hot100_ids['twogram_title'] = hot100_ids.loc[:,['orig_title','spotify_title']].apply(twogram_distance,axis=1)

# verify if spotify title contains original title and spotify artist contains original artist or "VARIOUS ARTISTS"
def eval_record(cols):
    # Compare regardless of white spacing
    str_cols = cols[:4]
    twogram_artist = cols[4]
    twogram_title = cols[5]
    orig_artist,orig_title,sp_artist,sp_title = (col.replace(' ','') for col in str_cols)
    if not (sp_artist.upper() == 'VARIOUSARTISTS'):
        if not (orig_artist in sp_artist) and not (sp_artist in orig_artist):
            if twogram_artist > 0.7:
                return False
            if twogram_artist >= 0.42:
                return np.nan
    if not (orig_title in sp_title) and not (sp_title in orig_title):
        if twogram_title > 0.7:
            return False
        if twogram_title >= 0.42:
            return np.nan
    return True

cond_not_verified = hot100_ids['verified'] == False
hot100_ids.loc[cond_not_verified,'verified'] = [eval_record(cols) for cols in zip(\
                                                        hot100_ids.loc[cond_not_verified,'orig_artist'], \
                                                        hot100_ids.loc[cond_not_verified,'orig_title'], \
                                                        hot100_ids.loc[cond_not_verified,'spotify_artist'], \
                                                        hot100_ids.loc[cond_not_verified,'spotify_title'], \
                                                        hot100_ids.loc[cond_not_verified,'twogram_artist'], \
                                                        hot100_ids.loc[cond_not_verified,'twogram_title'])]

print("Verified: {}\nNot Verified: {}\nUnknown: {}".format(len(hot100_ids[hot100_ids['verified'] == True]),len(hot100_ids[hot100_ids['verified'] == False]),(len(hot100_ids[hot100_ids['verified'].isnull()]))))
# Out:
# Verified: 20924
# Not Verified: 685
# Unknown: 230

# %% [markdown]
# The above cleaning allowed for the majority of observations to be matched. We're left with 230 titles that were too similar to automatically dismiss and too distant to accept as an automatic match. I'll review these observations manually below.

# %%
# Edge cases show table in full (max 400 in this case)
pd.options.display.max_rows = 400
hot100_ids[hot100_ids['verified'].isnull()]
# Out:
#                      iterator                                     filename  \
# 159    0LHzd11GIXVmND7TfQnGiy  ./data/interim/hot100/hot100_1992-11-09.csv
# 306    08SS3icN92vGmywytG8wK5  ./data/interim/hot100/hot100_1977-06-13.csv
# 334    09r0WIkaiL5fzAwBVLKWfy  ./data/interim/hot100/hot100_1977-06-13.csv
# 361    2FhwclPOq1BFSodmaseNRX  ./data/interim/hot100/hot100_1980-06-16.csv
# 553    0Rl0uAVTKl4eCjkSdsXGPr  ./data/interim/hot100/hot100_1966-06-20.csv
# 583    1IYn7ytdb8byvHKS7S3Cat  ./data/interim/hot100/hot100_1966-06-20.csv
# 704    7GTePWJ22W5STguGf16LLg  ./data/interim/hot100/hot100_1990-09-03.csv
# 751    67eX1ovaHyVPUinMHeUtIM  ./data/interim/hot100/hot100_1982-10-25.csv
# 760    43btz2xjMKpcmjkuRsvxyg  ./data/interim/hot100/hot100_1982-10-25.csv
# 765    0Of5lCNEqh62twRkQIOLuK  ./data/interim/hot100/hot100_1982-10-25.csv
# 896    5tnm4SMBzHcnFF6dnVNNJ7  ./data/interim/hot100/hot100_1975-10-20.csv
# 1114   0BszQDSiPwi5K7hNWfzWH8  ./data/interim/hot100/hot100_1987-12-07.csv
# 1168   7FtORS5qspEVqRGLTgLYwv  ./data/interim/hot100/hot100_1987-12-07.csv
# 1400   4Ah5bNVgK4dQ7w4BRyBdzI  ./data/interim/hot100/hot100_1978-10-23.csv
# 1450   7AGoGBfAGDFD6419a60e81  ./data/interim/hot100/hot100_1962-05-21.csv
# 1555   4dASQiO1Eoo3RJvt74FtXB  ./data/interim/hot100/hot100_2016-12-05.csv
# 1558   31XvIIkAoO5PDongqRuyWX  ./data/interim/hot100/hot100_2016-12-05.csv
# 1591   3GrH2iOYpYAqfzFPAi0ZUI  ./data/interim/hot100/hot100_1993-07-26.csv
# 1818   130osY0woeFCu77M4cBniA  ./data/interim/hot100/hot100_1975-09-29.csv
# 1821   234pZV6o8NoJoEnW56q8u9  ./data/interim/hot100/hot100_1975-09-29.csv
# 1827   2AhzqFDN9vO3htGvRrTVtG  ./data/interim/hot100/hot100_1975-09-29.csv
# 1860   0fXd3B3PbDr1fQvgZ2ZLfV  ./data/interim/hot100/hot100_1965-06-14.csv
# 1942   7fPXqb7yuGbSl0ZM3EddHx  ./data/interim/hot100/hot100_1983-01-03.csv
# 2026   5Z5ZfEUCDN7lGrobPwXHLJ  ./data/interim/hot100/hot100_1981-10-05.csv
# 2037   1ngH7sRyID6dr51y6K8AmF  ./data/interim/hot100/hot100_1981-10-05.csv
# 2156   6LpYKfPDviJJDWNDOrtnoA  ./data/interim/hot100/hot100_2005-04-11.csv
# 2196   0vFmCEzqAW5aXFTrGlR7j8  ./data/interim/hot100/hot100_1965-06-28.csv
# 2213   2VZzXJX14IZOmdXN2MuH9j  ./data/interim/hot100/hot100_1983-01-17.csv
# 2231   08VX2y1C02459ZYpta3dct  ./data/interim/hot100/hot100_1990-10-22.csv
# 2472   0w4XPJAG9ffcucyEGVbqPm  ./data/interim/hot100/hot100_1979-06-18.csv
# 2514   6lSVidZXCnOnYAWcgIqVDF  ./data/interim/hot100/hot100_1979-06-18.csv
# 2530   07V2lH4IMb5Jx9k49X4bY4  ./data/interim/hot100/hot100_1979-06-18.csv
# 2563   4HQP1WwHg9G9IVYqNdXyDO  ./data/interim/hot100/hot100_2002-10-28.csv
# 2634   2fn0t9vBTyPySe8PciU197  ./data/interim/hot100/hot100_1986-04-28.csv
# 3359   3cf5jnygf67JWEBBCbsg0F  ./data/interim/hot100/hot100_1974-04-22.csv
# 3434   3tvqPPpXyIgKrm4PR9HCf0  ./data/interim/hot100/hot100_1965-04-05.csv
# 3692   1XkVDfAdPpjFLCGWaWmF4D  ./data/interim/hot100/hot100_1982-05-10.csv
# 3738   1o9CxGhys8FG1YXMlaQWJ1  ./data/interim/hot100/hot100_1989-10-09.csv
# 3987   0XOuVAHsANAWw0LF0Yxkw5  ./data/interim/hot100/hot100_1984-10-22.csv
# 4077   1mzAgAg2Bd4AMwphrbIIMv  ./data/interim/hot100/hot100_1960-08-22.csv
# 4099   6cW2oRqcGKkyTasmiYu2FZ  ./data/interim/hot100/hot100_1960-08-22.csv
# 4127   2qMLLAya8vpzalveV5L4J1  ./data/interim/hot100/hot100_1960-08-22.csv
# 4387   7ifcMEyCUJVxh2gG1vyPtz  ./data/interim/hot100/hot100_2009-07-20.csv
# 4501   2AgBtTjP0OGJH5GoZWjpay  ./data/interim/hot100/hot100_1971-06-14.csv
# 4587   6WF1XcHrpVznfDiYjDSGly  ./data/interim/hot100/hot100_1961-07-10.csv
# 5013   5bO8uv2VQ0JTBDpNyrV1qH  ./data/interim/hot100/hot100_1991-04-08.csv
# 5019   3o8ls4KmiVYMymyiHuZtSi  ./data/interim/hot100/hot100_1991-04-08.csv
# 5033   4z8D58IC56O0JH2B818SkX  ./data/interim/hot100/hot100_1981-05-18.csv
# 5044   4qv7YSyt5UV8LvrXyE8sGn  ./data/interim/hot100/hot100_1981-05-18.csv
# 5072   4kik1yiPf2UJ4qd991qnwK  ./data/interim/hot100/hot100_1981-05-18.csv
# 5153   1sfO8OEGGiySbdm7BBkWP8  ./data/interim/hot100/hot100_1967-02-27.csv
# 5255   1aIh8C6OpXxOdM4pJatdIW  ./data/interim/hot100/hot100_1969-12-15.csv
# 5309   5eSl5nWXcvIe3eFsHOEspc  ./data/interim/hot100/hot100_1969-12-15.csv
# 5326   7HwcH5CiJzuUzspuOqOJQa  ./data/interim/hot100/hot100_1969-12-01.csv
# 5447   4oy4gZOLCTwMh2FjNo5RQJ  ./data/interim/hot100/hot100_1962-07-30.csv
# 5449   5Gei3XPSL1AWAntiZ6TgXD  ./data/interim/hot100/hot100_1962-07-30.csv
# 5454   4KmaO186C0dNwLHYa00Esu  ./data/interim/hot100/hot100_1962-07-30.csv
# 5470   6l9NYgYpn6LRTMNKvcMx0A  ./data/interim/hot100/hot100_1962-07-30.csv
# 5496   7xG1fakElLbxwyr9eyGEK6  ./data/interim/hot100/hot100_1995-09-18.csv
# 5669   4lJNen4SMTIJMahALc3DcB  ./data/interim/hot100/hot100_2018-10-22.csv
# 5936   2ZCdJPn8aFVd2CdmemNhLV  ./data/interim/hot100/hot100_1973-07-02.csv
# 6036   1lfjTOtTRUDkzcmahA4lcs  ./data/interim/hot100/hot100_1995-09-25.csv
# 6110   51nRQic7PFMD4NsdRj6soX  ./data/interim/hot100/hot100_2002-05-20.csv
# 6143   0c7h6Zc9XzMlQYArXtIIKt  ./data/interim/hot100/hot100_1970-10-12.csv
# 6292   2NkDQv8y2DkoYQURdiZCOk  ./data/interim/hot100/hot100_2007-07-16.csv
# 6714   1EungMlGWzS9JjEIerBXHl  ./data/interim/hot100/hot100_1989-07-10.csv
# 6944   6Ui2yvA0D5bXxZiPFWd47y  ./data/interim/hot100/hot100_1997-06-23.csv
# 7019   00meczE1jpLTX0BBzIGrAR  ./data/interim/hot100/hot100_1962-10-29.csv
# 7023   2Q7HyvRr2lkoDcyD0rBrwz  ./data/interim/hot100/hot100_1962-10-29.csv
# 7034   5TdCUrQdTWZoTSAZH7Pfup  ./data/interim/hot100/hot100_1962-10-29.csv
# 7073   0NpvdCO506uO58D4AbKzki  ./data/interim/hot100/hot100_1962-10-29.csv
# 7230   0KlTTi4DXQy3AnB7cyIN1T  ./data/interim/hot100/hot100_2008-06-02.csv
# 7830   4zzBhwmZCd1laUNgErXZIT  ./data/interim/hot100/hot100_1979-08-20.csv
# 7889   2aIXrAbyO9HvrlWGWfpfKa  ./data/interim/hot100/hot100_1962-12-10.csv
# 7899   2Du6IbzikdqDOSYLJQwT12  ./data/interim/hot100/hot100_1962-12-10.csv
# 8077   18ocy9Be9SxWEEnOLGDfkS  ./data/interim/hot100/hot100_1973-05-07.csv
# 8086   2n57bbhDsRMvUdUtuqIYxN  ./data/interim/hot100/hot100_1973-05-07.csv
# 8176   7cKKQIQt7no6VkHmcSwguE  ./data/interim/hot100/hot100_2003-01-27.csv
# 8236   0szxZG3QmQpMxrzmOjfDlm  ./data/interim/hot100/hot100_1996-12-09.csv
# 8398   2tux0ui8n2qdHdGpBnkhol  ./data/interim/hot100/hot100_1973-02-26.csv
# 8923   0Y6cPgjGPuSQsvChxA1U48  ./data/interim/hot100/hot100_1964-10-12.csv
# 8931   2hLB8P5TOz1lr7IzRCkXyi  ./data/interim/hot100/hot100_1964-10-12.csv
# 8948   1Ds4fOZtxhUh9N9pOVbALx  ./data/interim/hot100/hot100_1976-07-19.csv
# 9309   6KceGfo54oVMtf7mc2m9DM  ./data/interim/hot100/hot100_1959-09-28.csv
# 9441   1eAI3b04GBpA1YQ84GNc8n  ./data/interim/hot100/hot100_1977-08-29.csv
# 9559   04CpLajxMkVmvNyRtmwlvg  ./data/interim/hot100/hot100_1977-08-15.csv
# 9580   5LjSxAIKwyZvQqJ04ZQ0Da  ./data/interim/hot100/hot100_1998-05-18.csv
# 9637   0Cwn4fq9ysV0PsfSew34bp  ./data/interim/hot100/hot100_1998-05-18.csv
# 9653   2iIeQdi360dvjmjDWrvryp  ./data/interim/hot100/hot100_1967-09-11.csv
# 9668   5Sx26i9lDxDHTOM5YvxVOt  ./data/interim/hot100/hot100_1967-09-11.csv
# 9710   72rQqO217uRMY46c7K8Ws6  ./data/interim/hot100/hot100_1963-04-29.csv
# 9721   5Uoei8258ZUDvpVfOXaI2i  ./data/interim/hot100/hot100_1963-04-29.csv
# 9805   37zpChlZkoFuScXLoiu0WE  ./data/interim/hot100/hot100_1984-05-28.csv
# 9901   77FpiIZMdHmJ2C0pyBvbBH  ./data/interim/hot100/hot100_1995-02-06.csv
# 10011  0loo1QzCmSXerjeZBUVLPG  ./data/interim/hot100/hot100_1969-10-13.csv
# 10067  4TlHAudhkMzNoj19RuzGr0  ./data/interim/hot100/hot100_1969-10-13.csv
# 10095  00U0pedRUMEzREpyRqbVT6  ./data/interim/hot100/hot100_1994-04-04.csv
# 10154  4C76SOnBa9eQDwOwe11hPz  ./data/interim/hot100/hot100_1963-04-15.csv
# 10217  0z0eaQhoBfyLAe2rfdODwd  ./data/interim/hot100/hot100_1968-11-18.csv
# 10378  6doSV1UQjyKxiNCnBnDTeG  ./data/interim/hot100/hot100_1998-12-28.csv
# 10407  0BsmelqdNWE1KBxNL5NIYF  ./data/interim/hot100/hot100_1964-07-20.csv
# 10443  5lkm09e9jxWGWZD5tramBJ  ./data/interim/hot100/hot100_1964-07-20.csv
# 10463  1qTELl4raNOJlIVybqP7Wi  ./data/interim/hot100/hot100_1964-07-20.csv
# 10492  1ZVgydICDwNpd9OMVbaAU0  ./data/interim/hot100/hot100_1975-07-07.csv
# 10556  5ndGYGQJGv1hbpTKD6gzLZ  ./data/interim/hot100/hot100_1974-06-24.csv
# 10619  4PEeZ2U4UfP2Jo8EtIOjus  ./data/interim/hot100/hot100_1966-11-07.csv
# 10623  5gC5dlIYKbVzH0lIhDtK7R  ./data/interim/hot100/hot100_1966-11-07.csv
# 10684  0K3i1MJwU4v0Aq0VdYZnPg  ./data/interim/hot100/hot100_1966-11-07.csv
# 10823  1blZP5x1XQSqQFpTy12rFh  ./data/interim/hot100/hot100_1993-09-20.csv
# 10862  5lk17ZE9flaFuXUerzxeYm  ./data/interim/hot100/hot100_2004-05-31.csv
# 10997  3lZpvPprN56RWqDqrKy9vl  ./data/interim/hot100/hot100_2014-04-21.csv
# 11409  76PjPbGl8IaVqJWV153oJn  ./data/interim/hot100/hot100_1965-04-12.csv
# 11617  4xR0HPOe0abZG0MZi8LYIv  ./data/interim/hot100/hot100_1964-02-10.csv
# 11622  0Kgjoj9gsmjqWWo46fved4  ./data/interim/hot100/hot100_1964-02-10.csv
# 11660  1v4ROufvjD8wEkfdyg3Yk1  ./data/interim/hot100/hot100_1964-02-10.csv
# 11741  1wanFD0LdAcrAdVbXuRbOM  ./data/interim/hot100/hot100_2015-07-13.csv
# 11962  35Z9SYT8AjvgvUag0H4iQt  ./data/interim/hot100/hot100_1986-01-27.csv
# 12049  2UArFZy4LUwTNFmoklSpvT  ./data/interim/hot100/hot100_1978-02-20.csv
# 12062  7nVQ8mo77KaUvhUQzh4vMy  ./data/interim/hot100/hot100_1978-02-20.csv
# 12150  0BAHLHtovypNchYFyfHMIG  ./data/interim/hot100/hot100_1968-03-18.csv
# 12655  5sPgxY0a6An6nA6ixuqp3t  ./data/interim/hot100/hot100_1960-11-14.csv
# 12836  1y0ZoHeeEd0XTT8X7SnSq3  ./data/interim/hot100/hot100_2008-11-24.csv
# 13006  7fu3Tv5rcoGD1PZV7s57WW  ./data/interim/hot100/hot100_1973-09-10.csv
# 13124  221899EK6HGwW9xBc8sfCq  ./data/interim/hot100/hot100_1972-01-03.csv
# 13147  3D97kRhZprR6RumFhDFIr4  ./data/interim/hot100/hot100_1977-03-21.csv
# 13225  3CsE03tv1HDiUjWofKy49P  ./data/interim/hot100/hot100_1964-12-14.csv
# 13510  51TkhgtuJJtGSocHWNUq5O  ./data/interim/hot100/hot100_1960-08-08.csv
# 13716  51rXHuKN8Loc4sUlKPODgH  ./data/interim/hot100/hot100_2018-05-28.csv
# 13796  15YtixaZ1VgE3fPfXahlzD  ./data/interim/hot100/hot100_2000-01-10.csv
# 13841  3XYFesodmK3EfNcFCC7zyw  ./data/interim/hot100/hot100_1997-03-10.csv
# 13925  10MhX3LZPs8VYMCfJnUOUe  ./data/interim/hot100/hot100_1980-11-24.csv
# 13935  5tSJcd6jMcFCyKnI5JTag4  ./data/interim/hot100/hot100_1980-11-24.csv
# 14000  24vZ7MPPD3nDR79JdAaMcy  ./data/interim/hot100/hot100_1958-11-03.csv
# 14121  18vT0ddyQSJTdQPGRpM0en  ./data/interim/hot100/hot100_1983-06-20.csv
# 14133  2X51AKflJTB6IVPwrbMtMS  ./data/interim/hot100/hot100_1978-10-09.csv
# 14260  1deYpfv1m5w1TmGz9xyKAn  ./data/interim/hot100/hot100_1970-12-28.csv
# 14372  2g8OuYXyWjNbLyVjFRGWDg  ./data/interim/hot100/hot100_1969-10-06.csv
# 14431  781tWONUGr5dV7U1xmDWeV  ./data/interim/hot100/hot100_1966-01-03.csv
# 14664  0q8U63zhji2yXn7i9xQ8IX  ./data/interim/hot100/hot100_1974-11-11.csv
# 14671  3NT269TRBguAiEH4H2tFsC  ./data/interim/hot100/hot100_1974-11-11.csv
# 14689  0w4s0d8Qtu0K8dyMcB2tw1  ./data/interim/hot100/hot100_1974-11-11.csv
# 14696  2Oot9guaaxLj7o4vBjW1SV  ./data/interim/hot100/hot100_1974-11-11.csv
# 14725  26voGOZnzXz6smS7D2riux  ./data/interim/hot100/hot100_1991-08-26.csv
# 14997  4yhnLvpinTUYsGVVOWXhUi  ./data/interim/hot100/hot100_1962-02-12.csv
# 15008  4yjYZQpjpeSBzIMFM5NVV6  ./data/interim/hot100/hot100_1962-02-12.csv
# 15045  2cdwkBvcf927tAUvCR2ggy  ./data/interim/hot100/hot100_1979-11-12.csv
# 15086  6DpvREtNKnyYkPgv9RHHPw  ./data/interim/hot100/hot100_1967-10-09.csv
# 15106  2aCOTUTsSh9018q7nTsdjm  ./data/interim/hot100/hot100_2007-12-24.csv
# 15258  1e6JFAdiYVCuBJ4hsQbCsf  ./data/interim/hot100/hot100_2011-06-06.csv
# 15333  3klgM4azrZNgZ0bsZ7G5I2  ./data/interim/hot100/hot100_1978-09-04.csv
# 15474  33YKKW1MaDUwq7GDw3WOqR  ./data/interim/hot100/hot100_1967-12-18.csv
# 15853  14zpTN39s1y9Mb0RrXiSFC  ./data/interim/hot100/hot100_1994-08-29.csv
# 15944  38SctZyQGZqE2yC9fNdzyD  ./data/interim/hot100/hot100_1972-06-26.csv
# 16018  3skk6UIXV4kepq2bdYy97g  ./data/interim/hot100/hot100_1971-11-22.csv
# 16079  3RxF3Mz5wprRMopI8fp9uF  ./data/interim/hot100/hot100_1994-08-01.csv
# 16090  1ePIjPuiQvrLKKYJhW7dPh  ./data/interim/hot100/hot100_1963-08-05.csv
# 16097  4AFLFG6pyvhBLC37FbDwc2  ./data/interim/hot100/hot100_1963-08-05.csv
# 16107  1WvcgDbT79xeAa7Mv0klkK  ./data/interim/hot100/hot100_1963-08-05.csv
# 16113  7bdlmyOAMwUwLmE85K8mN2  ./data/interim/hot100/hot100_1963-08-05.csv
# 16126  6Pzbv8zwmq31mq998fBG5i  ./data/interim/hot100/hot100_1963-08-05.csv
# 16280  6a1VBGBizYx9mQl9eqyamP  ./data/interim/hot100/hot100_1967-05-01.csv
# 16289  2gFfG8Ick2LGOzFHiWOV22  ./data/interim/hot100/hot100_1967-05-01.csv
# 16295  4vsJejr0UiQDppgqDlQVZe  ./data/interim/hot100/hot100_1967-05-01.csv
# 16300  4vxOl0RGNzW05Dp6zyvUo0  ./data/interim/hot100/hot100_1967-05-15.csv
# 16335  2BU4dK1fu1CFLjTBz7ju7Q  ./data/interim/hot100/hot100_1981-02-02.csv
# 16354  1dMNHdoHRZ5k02EobCGgx0  ./data/interim/hot100/hot100_1981-02-02.csv
# 16442  4Zibbwj1STIuxLT3WdEY67  ./data/interim/hot100/hot100_1971-08-02.csv
# 16951  0k3fBeBIcok5gbYQyQbxP5  ./data/interim/hot100/hot100_1982-07-12.csv
# 17026  4mLbbnDWp5NoJXP0WxjcmA  ./data/interim/hot100/hot100_1959-10-19.csv
# 17032  1dd9iqRXvxHLcDwHQcYZzj  ./data/interim/hot100/hot100_1964-09-21.csv
# 17071  4MRhEMGSsBTaBX8IBNCe1b  ./data/interim/hot100/hot100_1965-08-16.csv
# 17075  5zmwXfoHO0s9WHN0k2Ntcu  ./data/interim/hot100/hot100_1965-08-16.csv
# 17126  4elVuCOp5pp4yzobTO5thA  ./data/interim/hot100/hot100_1963-03-18.csv
# 17141  6LbOC2J8ojSTwE6qIS4Eyh  ./data/interim/hot100/hot100_1966-08-22.csv
# 17204  39fC5AxqLsNpZf5FtTwNgP  ./data/interim/hot100/hot100_1966-08-22.csv
# 17690  55rto3DG5ivOjMzwOAijA6  ./data/interim/hot100/hot100_1971-01-18.csv
# 17768  3TyhfD8fjfkzg9ujAM9qPO  ./data/interim/hot100/hot100_1986-08-11.csv
# 17876  6Qu1yi6M7Z0BoH39bSiBfu  ./data/interim/hot100/hot100_1979-03-05.csv
# 17877  5S1IUPueD0xE0vj4zU3nSf  ./data/interim/hot100/hot100_2018-07-02.csv
# 18359  22AbXxQbMdVqEz7xJjhccG  ./data/interim/hot100/hot100_2005-08-01.csv
# 18438  2x1LQq8lsUzAA2wNj8yjC9  ./data/interim/hot100/hot100_1975-02-24.csv
# 18523  0XXnQWgIdaUsp2twWmqmU3  ./data/interim/hot100/hot100_1979-01-29.csv
# 18561  63Vw8PU3ps8TAxDdHAUTMX  ./data/interim/hot100/hot100_1966-11-28.csv
# 18595  2WEDk1uASGLzY30DxzzRqC  ./data/interim/hot100/hot100_1965-01-25.csv
# 18627  5BSlukklfUTrmzmsuctmMr  ./data/interim/hot100/hot100_1995-05-08.csv
# 18816  0NYARSjTaMT67cbW3JozJI  ./data/interim/hot100/hot100_1963-10-28.csv
# 18837  15B1limEYsrV2tKWeUjAnS  ./data/interim/hot100/hot100_1963-10-14.csv
# 18858  66nWGFaJUCa5MDlaMPmcRR  ./data/interim/hot100/hot100_1980-02-11.csv
# 18891  0ct6r3EGTcMLPtrXHDvVjc  ./data/interim/hot100/hot100_2014-10-20.csv
# 19035  4XcUFQNTiX4IHmA4K51snP  ./data/interim/hot100/hot100_1983-10-31.csv
# 19063  293eqWHDIwj36Cd1s33TLA  ./data/interim/hot100/hot100_1960-12-19.csv
# 19208  4wT8DrJCjWacytnqk8L9is  ./data/interim/hot100/hot100_1968-07-08.csv
# 19276  6LEXD2N3PxSmu4BMUHjaTb  ./data/interim/hot100/hot100_1968-09-30.csv
# 19448  2xjwQklxykSEara5fTEKCK  ./data/interim/hot100/hot100_1995-03-27.csv
# 19527  1C5TdPivZzdI5bWzRy5hNk  ./data/interim/hot100/hot100_1967-04-24.csv
# 19532  2ZlpHzD786VSWcPc4mdLDX  ./data/interim/hot100/hot100_1967-04-24.csv
# 19608  1jRnSVA3PfS0BhoKylM4E2  ./data/interim/hot100/hot100_1968-02-05.csv
# 19631  5dZiQVyXv66lYP2SSm8Ne1  ./data/interim/hot100/hot100_1986-09-22.csv
# 19680  4bsCuHdTpVqf90EJ7oowMX  ./data/interim/hot100/hot100_1969-04-07.csv
# 19706  6A9nyMBdNUzVcFHZUEZ71F  ./data/interim/hot100/hot100_2007-11-05.csv
# 19721  4wwLIS4ONohVyhVb5zCPOH  ./data/interim/hot100/hot100_1980-12-29.csv
# 19737  3pYKJaLiixRcDFfcNhxZKK  ./data/interim/hot100/hot100_2006-10-30.csv
# 19828  2G597vEgxsvckPwocEHY9Y  ./data/interim/hot100/hot100_1962-06-04.csv
# 19831  1Fr9lN5agksbmJYi0qlWmG  ./data/interim/hot100/hot100_1962-06-04.csv
# 19963  2370aszHFScynGrF9tN7lC  ./data/interim/hot100/hot100_1960-12-26.csv
# 20128  5VgcM58bybW45T2WgTdbeY  ./data/interim/hot100/hot100_1969-01-20.csv
# 20135  2M5VVklnIl2c5yuDm8kZnf  ./data/interim/hot100/hot100_1971-05-24.csv
# 20260  2miRjPqq8UUQA5z5Z9BL0u  ./data/interim/hot100/hot100_1965-05-24.csv
# 20485  5z6kXfZFFPYgJAK7mwq5wh  ./data/interim/hot100/hot100_1965-07-19.csv
# 20539  1msuiw6pnXYfxZ7Edyit9U  ./data/interim/hot100/hot100_2001-01-01.csv
# 20649  53435bte8yCZDBipvsq7cm  ./data/interim/hot100/hot100_1985-07-01.csv
# 20711  4PYW9HJOdzwvTu6XtFXoWG  ./data/interim/hot100/hot100_1978-03-13.csv
# 20726  3oRMeMMJ1xUhBBpy2iGE2g  ./data/interim/hot100/hot100_2009-01-19.csv
# 20866  5OmHb9bbZokD1iNkp3axo2  ./data/interim/hot100/hot100_1963-02-11.csv
# 21001  0ElQWopuhQ10wgGouWSVlR  ./data/interim/hot100/hot100_2005-12-12.csv
# 21103  5jSAfX8SJVD5uzFyLlTVwo  ./data/interim/hot100/hot100_2004-08-30.csv
# 21177  5xS3g1B4lSplD8F8Rt2XzF  ./data/interim/hot100/hot100_1964-08-24.csv
# 21194  7zI8PUaeTfj2kgmqHnyIO8  ./data/interim/hot100/hot100_1961-04-03.csv
# 21318  3woGPx9i3RByafS2lWKGVP  ./data/interim/hot100/hot100_1961-08-14.csv
# 21534  3cCUAhulFXxN9CZRr5inpe  ./data/interim/hot100/hot100_1990-08-13.csv
# 21557  0slyXInD5PEFYidY4pgZhC  ./data/interim/hot100/hot100_1972-12-11.csv
# 21592  3VrZjDtGoiZHqrHxjbGUd9  ./data/interim/hot100/hot100_1967-06-12.csv
# 21711  3JeN8VELWzS0j91jddgsYb  ./data/interim/hot100/hot100_1959-11-30.csv
# 21771  677oYgkn4m90Zvq4lQH2B8  ./data/interim/hot100/hot100_1962-05-14.csv
# 21773  36KNwRx1fpLhHthtq4W9ym  ./data/interim/hot100/hot100_1972-04-10.csv
# 21823  5yEpB2g3CbuVk4YmAkzkOK  ./data/interim/hot100/hot100_1996-09-30.csv
# 21861  39LSfgIQHJwKi3gBDXmcwi  ./data/interim/hot100/hot100_1967-09-18.csv
# 21924  1sNcQ93heFSMr9aI6NhP4z  ./data/interim/hot100/hot100_1980-03-10.csv
# 22014  3F37xwBMpBxOqxQ7MPqArq  ./data/interim/hot100/hot100_1967-07-24.csv
# 22158  7dZOwXFupdzK8Zi4iTJlXJ  ./data/interim/hot100/hot100_2008-11-17.csv
#
#                                                   artist  \
# 159                                           Elton John
# 306                                The Steve Miller Band
# 334                            The Sanford/Townsend Band
# 361                                   Average White Band
# 553                    James Brown And The Famous Flames
# 583                          Ray Conniff And The Singers
# 704                                            The Party
# 751                                          John Cougar
# 760                                          John Cougar
# 765                                          Evelyn King
# 896                                        The 4 Seasons
# 1114                                         Eric Carmen
# 1168                                                Deja
# 1400                                         The Beatles
# 1450                                        The Volume's
# 1555   Lil Wayne, Wiz Khalifa & Imagine Dragons With ...
# 1558                     Calvin Harris Featuring Rihanna
# 1591                                                 TLC
# 1818                                                 AWB
# 1821                     John Williams/"Jaws" Soundtrack
# 1827                                         The Osmonds
# 1860                                  Unit Four plus Two
# 1942                                         John Cougar
# 2026                                       The Dirt Band
# 2037                                         Evelyn King
# 2156                       Frankie J Featuring Baby Bash
# 2196                                    Herman's Hermits
# 2213                                         Evelyn King
# 2231                                             Biscuit
# 2472                                      Bonnie Pointer
# 2514                                        The Jacksons
# 2530                           Manfred Mann's Earth Band
# 2563                                         Las Ketchup
# 2634                                Mike + The Mechanics
# 3359                                           Mocedades
# 3434                                       Andy Williams
# 3692                                            Stars On
# 3738                                            The Cure
# 3987                                        The Jacksons
# 4077                                   The Kingston Trio
# 4099                                       Etta & Harvey
# 4127                                       Bobby Marchan
# 4387                                               LMFAO
# 4501                                         Bobby Bland
# 4587                                           Damita Jo
# 5013                                           The Party
# 5019                                    Voices That Care
# 5033                                         John Cougar
# 5044                                        The Jacksons
# 5072                                         Phoebe Snow
# 5153                                  The Rolling Stones
# 5255                                         The Beatles
# 5309                                        The Illusion
# 5326                                               Smith
# 5447                                         Baby Cortez
# 5449                                       Nelson Riddle
# 5454                                    The Springfields
# 5470                                         The Duprees
# 5496                                    Vanessa Williams
# 5669                Labrinth, Sia & Diplo Present... LSD
# 5936                                           The Sweet
# 6036                                      The Rembrandts
# 6110                                    Pilar Montenegro
# 6143                                 Grand Funk Railroad
# 6292                     Timbaland Featuring Keri Hilson
# 6714                                          De La Soul
# 6944                                       Sneaker Pimps
# 7019                                       The 4 Seasons
# 7023                                    The Springfields
# 7034                                        The Crystals
# 7073                                       The 4 Seasons
# 7230                                          David Cook
# 7830                                         Bad Company
# 7889                                       The 4 Seasons
# 7899                                     Flatt & Scruggs
# 8077                                        Neil Diamond
# 8086                                    The Mystic Moods
# 8176                                  Smilez & Southstar
# 8236                                            Le Click
# 8398                                    Jermaine Jackson
# 8923                                         The Zombies
# 8931                                       Billy Strange
# 8948                                        Donny Osmond
# 9309                                         Della Reese
# 9441                                         The Ramones
# 9559                                       The 4 Seasons
# 9580                                          Elton John
# 9637                                        Busta Rhymes
# 9653                                       The Yardbirds
# 9668                                        Otis & Carla
# 9710                                       The 4 Seasons
# 9721                     Henry Mancini And His Orchestra
# 9805                                        Juice Newton
# 9901                                            Stevie B
# 10011                                      The 4 Seasons
# 10067                                The Brooklyn Bridge
# 10095                                            Madonna
# 10154                                      The 4 Seasons
# 10217                                     Wilson Pickett
# 10378                                       Adam Sandler
# 10407                                      The 4 Seasons
# 10443                                 The Rolling Stones
# 10463                                   The Chartbusters
# 10492                                                AWB
# 10556                                   William DeVaughn
# 10619                 ? (Question Mark) & The Mysterians
# 10623                      Tamiko Jones with Herbie Mann
# 10684                                        The Hollies
# 10823                                           Babyface
# 10862                                           Lonestar
# 10997                                 YG Featuring Drake
# 11409                                      George & Gene
# 11617                                      The 4 Seasons
# 11622                                The Dave Clark Five
# 11660                                      The 4 Seasons
# 11741                            Janelle Monae & Jidenna
# 11962                                       Eugene Wilde
# 12049                                       Donna Summer
# 12062                                    Waylon & Willie
# 12150                  James Brown And The Famous Flames
# 12655                   Hank Ballard And The Midnighters
# 12836                                Coldplay With Jay-Z
# 13006                               The Hues Corporation
# 13124                                         Peter Nero
# 13147                                       The Jacksons
# 13225                                     Walter Jackson
# 13510                                      Conway Twitty
# 13716     Jay Rock, Kendrick Lamar, Future & James Blake
# 13796                                                IMx
# 13841                                                Tre
# 13925                                          The Kings
# 13935                                        John Cougar
# 14000                                      Gordon MacRae
# 14121                                      Martin Briley
# 14133                                   Barbra Streisand
# 14260                                       Jim Ed Brown
# 14372                             Supremes & Temptations
# 14431                                        The Animals
# 14664                                 Brother To Brother
# 14671                                           Latimore
# 14689                               The Hues Corporation
# 14696                                Tony Orlando & Dawn
# 14725                              Prince And The N.P.G.
# 14997                                       The Platters
# 15008                                         Huey Smith
# 15045                                        John Cougar
# 15086                        The Jimi Hendrix Experience
# 15106                                        Chris Brown
# 15258                                 Don Omar & Lucenzo
# 15333                                      The Dirt Band
# 15474                                           Bee Gees
# 15853                               The Notorious B.I.G.
# 15944                                   Jackie DeShannon
# 16018                                                Yes
# 16079                               The Crooklyn Dodgers
# 16090                                       The Supremes
# 16097                                      The 4 Seasons
# 16107                                      Allan Sherman
# 16113                                      Steve & Eydie
# 16126                                      The 4 Seasons
# 16280                      Nancy Sinatra & Frank Sinatra
# 16289                                       Otis & Carla
# 16295                                Cannonball Adderley
# 16300                                        O.V. Wright
# 16335                                       The Jacksons
# 16354                                     Blues Brothers
# 16442                                       Paul Stookey
# 16951                                      Stevie Wonder
# 17026                                         Bo Diddley
# 17032                                The Dave Clark Five
# 17071                                       The Drifters
# 17075                                      G.L. Crockett
# 17126                                Carl Butler & Pearl
# 17141                                               Love
# 17204                                         Mel Carter
# 17690                               The Statler Brothers
# 17768                                            Klymaxx
# 17876                                    The Wonder Band
# 17877                            2 Chainz, Drake & Quavo
# 18359                           Damian "Jr. Gong" Marley
# 18438                                                AWB
# 18523                                       Tasha Thomas
# 18561                 ? (Question Mark) & The Mysterians
# 18595                                       Lorne Greene
# 18627                                         Tracy Byrd
# 18816                                      The 4 Seasons
# 18837                                      The 4 Seasons
# 18858                                        John Cougar
# 18891                                             Avicii
# 19035                                       Quarterflash
# 19063                                       The Ramblers
# 19208                             The Sweet Inspirations
# 19276                        The Jimi Hendrix Experience
# 19448                                             Prince
# 19527                 ? (Question Mark) & The Mysterians
# 19532                                        Ben E. King
# 19608                                       Otis & Carla
# 19631                                     David Lee Roth
# 19680                             Supremes & Temptations
# 19706                                       Fall Out Boy
# 19721                                      The 4 Seasons
# 19737                                        Tenacious D
# 19828                                       Rene And Ray
# 19831                         Kenny Ball and his Jazzmen
# 19963                                      Etta & Harvey
# 20128                                        Nina Simone
# 20135                                            Red Eye
# 20260                                         Brenda Lee
# 20485                                 Unit Four plus Two
# 20539                                         Faith Hill
# 20649                                    Stephanie Mills
# 20711                                    Ronnie McDowell
# 20726                                   Miranda Cosgrove
# 20866                                          Sam Cooke
# 21001                       Trick-Trick Featuring Eminem
# 21103                                             Brandy
# 21177                                      The 4 Seasons
# 21194                                        Jimmy Jones
# 21318                                     Steve Lawrence
# 21534                                               Bang
# 21557                                     Delbert & Glen
# 21592                 ? (Question Mark) & The Mysterians
# 21711                                           5 Satins
# 21771                                  The Kingston Trio
# 21773                                       Peter Yarrow
# 21823                    Tom Petty And The Heartbreakers
# 21861                                      Pretty Purdie
# 21924                                          Engelbert
# 22014                         Davie Allan And The Arrows
# 22158                                         Buckcherry
#
#                                                    title  \
# 159                                              The One
# 306                                         Jet Airliner
# 334                            Smoke From A Distant Fire
# 361                                Let's Go 'round Again
# 553                       It's A Man's Man's Man's World
# 583                                   Somewhere, My Love
# 704                                      Summer Vacation
# 751                                        Hurts So Good
# 760                                         Jack & Diane
# 765                                       Love Come Down
# 896                                        Who Loves You
# 1114                  Hungry Eyes (From "Dirty Dancing")
# 1168                                  You And Me Tonight
# 1400   Sgt. Pepper's Lonely Hearts Club Band/With A L...
# 1450                                          I Love You
# 1555                                     Sucker For Pain
# 1558                           This Is What You Came For
# 1591                   Get It Up (From "Poetic Justice")
# 1818                          If I Ever Lose This Heaven
# 1821                      Main Title (Theme From "Jaws")
# 1827                                       The Proud One
# 1860                                   Concrete And Clay
# 1942                                  Hand To Hold On To
# 2026                                     Fire In The Sky
# 2037                                         I'm In Love
# 2156                              Obsession (No Es Amor)
# 2196                                I'm Henry VIII, I Am
# 2213                           Betcha She Don't Love You
# 2231                              Biscuit's In The House
# 2472                           Heaven Must Have Sent You
# 2514                Shake Your Body (Down To The Ground)
# 2530                                       You Angel You
# 2563                          The Ketchup Song (Hey Hah)
# 2634                Silent Running (On Dangerous Ground)
# 3359                            Eres Tu (Touch The Wind)
# 3434                           ......And Roses And Roses
# 3692                                     Stars on 45 III
# 3738                                           Love Song
# 3987                                             Torture
# 4077                                     Bad Man Blunder
# 4099                                 If I Can't Have You
# 4127             There's Something On Your Mind (Part 2)
# 4387                                  I'm In Miami Trick
# 4501                                           I'm Sorry
# 4587                                       I'll Be There
# 5013                                          That's Why
# 5019                                    Voices That Care
# 5033                      Ain't Even Done With The Night
# 5044                                     Can You Feel It
# 5072                                 Mercy, Mercy, Mercy
# 5153                      Let's Spend The Night Together
# 5255                             Come Together/Something
# 5309                                            Together
# 5326                                       Baby It's You
# 5447                                          Rinky Dink
# 5449                                      Route 66 Theme
# 5454                   Silver Threads And Golden Needles
# 5470                                    You Belong To Me
# 5496              Colors Of The Wind (From "Pocahontas")
# 5669                                       Thunderclouds
# 5936                                         Blockbuster
# 6036      I'll Be There For You/This House Is Not A Home
# 6110                                  Quitame Ese Hombre
# 6143                   Closer To Home (I'm Your Captain)
# 6292                                       The Way I Are
# 6714                                     Me Myself And I
# 6944                                       6 Underground
# 7019                                 Big Girls Don't Cry
# 7023                       Dear Hearts And Gentle People
# 7034                                        He's A Rebel
# 7073                                              Sherry
# 7230                                               Hello
# 7830                                    Gone, Gone, Gone
# 7889                       Santa Claus Is Coming To Town
# 7899                          The Ballad Of Jed Clampett
# 8077               "Cherry Cherry" from Hot August Night
# 8086                                          Cosmic Sea
# 8176                           Tell Me (What's Goin' On)
# 8236                                Tonight Is The Night
# 8398                                        Daddy's Home
# 8923                                     She's Not There
# 8931                                The James Bond Theme
# 8948                                      C'mon Marianne
# 9309                                      Don't You Know
# 9441                             Sheena Is A Punk Rocker
# 9559                                       Down The Hall
# 9580   Candle In The Wind 1997/Something About The Wa...
# 9637                       Turn It Up [Remix]/Fire It Up
# 9653                                Ha Ha Said The Clown
# 9668                                       Knock On Wood
# 9710                                 Ain't That A Shame!
# 9721                              Days Of Wine And Roses
# 9805                                       A Little Love
# 9901                        Dream About You/Funky Melody
# 10011          And That Reminds Me (My Heart Reminds Me)
# 10067                            You'll Never Walk Alone
# 10095                 I'll Remember (From "With Honors")
# 10154                                    Walk Like A Man
# 10217                                   A Man And A Half
# 10378                                  The Chanukah Song
# 10407                                              Alone
# 10443                                  It's All Over Now
# 10463                                      She's The One
# 10492                                       Cut The Cake
# 10556                       Be Thankful For What You Got
# 10619                                           96 Tears
# 10623                                  A Man And A Woman
# 10684                                     Stop Stop Stop
# 10823                                For The Cool In You
# 10862                                  Let's Be Us Again
# 10997                                   Who Do You Love?
# 11409      I've Got Five Dollars And It's Saturday Night
# 11617                                     Dawn (Go Away)
# 11622                                      Glad All Over
# 11660                                               Stay
# 11741                                               Yoga
# 11962                               Don't Say No Tonight
# 12049                                         I Love You
# 12062  Mammas Don't Let Your Babies Grow Up To Be Cow...
# 12150                                  I Got The Feelin'
# 12655                       Let's Go, Let's Go, Let's Go
# 12836                                              Lost!
# 13006                           Freedom For The Stallion
# 13124                         Theme From "Summer Of '42"
# 13147                                     Enjoy Yourself
# 13225                                      It's All Over
# 13510                                         She's Mine
# 13716                                        King's Dead
# 13796                                     Stay The Night
# 13841                                     Take Your Time
# 13925               Switchin' To Glide/This Beat Goes On
# 13935                                          This Time
# 14000                                         The Secret
# 14121                               The Salt In My Tears
# 14133    Love Theme From "Eyes Of Laura Mars" (Prisoner)
# 14260                                            Morning
# 14372                                         The Weight
# 14431                                       It's My Life
# 14664                                      In The Bottle
# 14671                            Let's Straighten It Out
# 14689                                       Rockin' Soul
# 14696                Steppin' Out (Gonna Boogie Tonight)
# 14725                                           Gett Off
# 14997                                         It's Magic
# 15008                                            Pop-Eye
# 15045                                     I Need A Lover
# 15086                                        Purple Haze
# 15106                                     This Christmas
# 15258                                       Danza Kuduro
# 15333                                   In For The Night
# 15474             (The Lights Went Out In) Massachusetts
# 15853                                 Juicy/Unbelievable
# 15944                                       Vanilla Ólay
# 16018              Your Move (I've Seen All Good People)
# 16079                         Crooklyn (From "Crooklyn")
# 16090                                A Breath Taking Guy
# 16097                                         Candy Girl
# 16107   Hello Mudduh, Hello Fadduh! (A Letter From Camp)
# 16113                                I Want To Stay Here
# 16126                                            Marlena
# 16280                                   Somethin' Stupid
# 16289                                              Tramp
# 16295                         Why? (Am I Treated So Bad)
# 16300                              Eight Men, Four Women
# 16335                                   Heartbreak Hotel
# 16354                                  Who's Making Love
# 16442                       Wedding Song (There Is Love)
# 16951                                            Do I Do
# 17026                                            Say Man
# 17032                                            Because
# 17071            I'll Take You Where The Music's Playing
# 17075                              It's A Man Down There
# 17126                            Don't Let Me Cross Over
# 17141                                         7 And 7 Is
# 17204                                        You You You
# 17690                                      Bed Of Rose's
# 17768              Man Size Love (From "Running Scared")
# 17876                                   Whole Lotta Love
# 17877                                       Bigger > You
# 18359                                 Welcome To Jamrock
# 18438                                 Pick Up The Pieces
# 18523                          Shoot Me (With Your Love)
# 18561                                    I Need Somebody
# 18595                                            The Man
# 18627                            The Keeper Of The Stars
# 18816                                   New Mexican Rose
# 18837                                That's The Only Way
# 18858                                     Small Paradise
# 18891                                           The Days
# 19035                               Take Another Picture
# 19063                                           Rambling
# 19208                                   To Love Somebody
# 19276                           All Along The Watchtower
# 19448                                      Purple Medley
# 19527                      Can't Get Enough Of You, Baby
# 19532                                Tears, Tears, Tears
# 19608                                        Lovey Dovey
# 19631                                       Goin' Crazy!
# 19680                             I'll Try Something New
# 19706                     I'm Like A Lawyer...(Me & You)
# 19721                            Spend The Night In Love
# 19737                                The Pick Of Destiny
# 19828                                  Queen Of My Heart
# 19831                         The Green Leaves Of Summer
# 19963                                           Spoonful
# 20128                           Ain't Got No; I Got Life
# 20135                                      Red Eye Blues
# 20260                                             No One
# 20485         You've Never Been In Love Like This Before
# 20539                           Where Are You Christmas?
# 20649                     Bit By Bit (Theme From Fletch)
# 20711                 I Love You, I Love You, I Love You
# 20726                                      About You Now
# 20866                                   Baby, Baby, Baby
# 21001                                  Welcome 2 Detroit
# 21103                                     Who Is She 2 U
# 21177                                          Sincerely
# 21194                                      I Told You So
# 21318                                            In Time
# 21534                                   Holding My Heart
# 21557                                I Received A Letter
# 21592                            Girl (You Captivate Me)
# 21711                                            Shadows
# 21771                                   Jane, Jane, Jane
# 21773                    Don't Ever Take Away My Freedom
# 21823                       Walls (From "She's The One")
# 21861                                       Funky Donkey
# 21924                                   Love's Only Love
# 22014                                     Devil's Angels
# 22158                                       Too Drunk...
#
#                                           spotify_artist  \
# 159                                      VARIOUS ARTISTS
# 306                                      THE ROCK HEROES
# 334                                 SANFORD AND TOWNSEND
# 361                                   AVERAGE WHITE BAND
# 553                    JAMES BROWN AND THE FAMOUS FLAMES
# 583                              THE RAY CONNIFF SINGERS
# 704                                 THE CHILLOUT PLAYERS
# 751                                      JOHN MELLENCAMP
# 760                                      JOHN MELLENCAMP
# 765                              EVELYN "CHAMPAGNE" KING
# 896                   FRANKIE VALLI AND THE FOUR SEASONS
# 1114                                     VARIOUS ARTISTS
# 1168                                             DEJÀ VU
# 1400                        THE BAND OF THE IRISH GUARDS
# 1450                                THE STATLER BROTHERS
# 1555       LIL WAYNE AND WIZ KHALIFA AND IMAGINE DRAGONS
# 1558                          SANDRO MARTINEZ AND SANDRA
# 1591                                                 TLC
# 1818                                  AVERAGE WHITE BAND
# 1821                                       JOHN WILLIAMS
# 1827                                         THE OSMONDS
# 1860                                          UNIT 4 + 2
# 1942                                     JOHN MELLENCAMP
# 2026                              NITTY GRITTY DIRT BAND
# 2037                             EVELYN "CHAMPAGNE" KING
# 2156                                           FRANKIE J
# 2196   GERRY AND THE PACEMAKERS  HERMANS HERMITS AND ...
# 2213                             EVELYN "CHAMPAGNE" KING
# 2231                  KING PLEASURE AND THE BISCUIT BOYS
# 2472                                 THE POINTER SISTERS
# 2514                                     MICHAEL JACKSON
# 2530                            MANFRED MANNS EARTH BAND
# 2563                                            LAS KALA
# 2634                                          B THE STAR
# 3359                                           MOCEDADES
# 3434                                       ANDY WILLIAMS
# ...
# 9710                                  AINT THAT A SHAME!        0.573529
# 9721                              DAYS OF WINE AND ROSES        0.426471
# 9805                                       A LITTLE LOVE        0.000000
# 9901                        DREAM ABOUT YOU FUNKY MELODY        0.000000
# 10011           AND THAT REMINDS ME  MY HEART REMINDS ME        0.573529
# 10067                             YOULL NEVER WALK ALONE        0.514706
# 10095                   ILL REMEMBER  FROM "WITH HONORS"        0.000000
# 10154                                    WALK LIKE A MAN        0.573529
# 10217                                   A MAN AND A HALF        0.000000
# 10378                                  THE CHANUKAH SONG        0.000000
# 10407                                              ALONE        0.573529
# 10443                                   ITS ALL OVER NOW        0.555556
# 10463                                       SHES THE ONE        0.380952
# 10492                                       CUT THE CAKE        0.694444
# 10556                       BE THANKFUL FOR WHAT YOU GOT        0.000000
# 10619                                           96 TEARS        0.444444
# 10623                                  A MAN AND A WOMAN        0.689655
# 10684                                     STOP STOP STOP        0.000000
# 10823                                FOR THE COOL IN YOU        0.000000
# 10862                                   LETS BE US AGAIN        0.000000
# 10997                                   WHO DO YOU LOVE?        0.866667
# 11409        IVE GOT FIVE DOLLARS AND ITS SATURDAY NIGHT        0.464286
# 11617                                      DAWN  GO AWAY        0.573529
# 11622                                      GLAD ALL OVER        0.631579
# 11660                                               STAY        0.573529
# 11741                                               YOGA        0.700000
# 11962                                DONT SAY NO TONIGHT        0.000000
# 12049                                         I LOVE YOU        0.000000
# 12062  MAMMAS DONT LET YOUR BABIES GROW UP TO BE COWBOYS        0.484848
# 12150                                   I GOT THE FEELIN        0.666667
# 12655                          LETS GO  LETS GO  LETS GO        0.000000
# 12836                                              LOST!        0.578947
# 13006                           FREEDOM FOR THE STALLION        0.225000
# 13124                          THEME FROM "SUMMER OF 42"        0.000000
# 13147                                     ENJOY YOURSELF        0.500000
# 13225                                       ITS ALL OVER        0.000000
# 13510                                          SHES MINE        0.000000
# 13716                                         KINGS DEAD        0.447917
# 13796                                     STAY THE NIGHT        0.562500
# 13841                                     TAKE YOUR TIME        0.636364
# 13925                SWITCHIN TO GLIDE THIS BEAT GOES ON        0.000000
# 13935                                          THIS TIME        0.566667
# 14000                                         THE SECRET        0.465517
# 14121                               THE SALT IN MY TEARS        0.700000
# 14133     LOVE THEME FROM "EYES OF LAURA MARS"  PRISONER        0.000000
# 14260                                            MORNING        0.583333
# 14372                                         THE WEIGHT        0.500000
# 14431                                        ITS MY LIFE        0.588235
# 14664                                      IN THE BOTTLE        0.600000
# 14671                             LETS STRAIGHTEN IT OUT        0.000000
# 14689                                        ROCKIN SOUL        0.225000
# 14696                  STEPPIN OUT  GONNA BOOGIE TONIGHT        0.000000
# 14725                                           GETT OFF        0.694444
# 14997                                          ITS MAGIC        0.000000
# 15008                                            POP EYE        0.444444
# 15045                                     I NEED A LOVER        0.566667
# 15086                                        PURPLE HAZE        0.518519
# 15106                                     THIS CHRISTMAS        0.000000
# 15258                                       DANZA KUDURO        0.700000
# 15333                                   IN FOR THE NIGHT        0.522727
# 15474              THE LIGHTS WENT OUT IN  MASSACHUSETTS        0.900000
# 15853                                 JUICY UNBELIEVABLE        0.000000
# 15944                                       VANILLA ÓLAY        0.000000
# 16018                YOUR MOVE  IVE SEEN ALL GOOD PEOPLE        0.000000
# 16079                          CROOKLYN  FROM "CROOKLYN"        0.825000
# 16090                                A BREATH TAKING GUY        0.000000
# 16097                                         CANDY GIRL        0.573529
# 16107    HELLO MUDDUH  HELLO FADDUH!  A LETTER FROM CAMP        0.000000
# 16113                                I WANT TO STAY HERE        0.500000
# 16126                                            MARLENA        0.573529
# 16280                                    SOMETHIN STUPID        0.693548
# 16289                                              TRAMP        0.517241
# 16295                          WHY?  AM I TREATED SO BAD        0.000000
# 16300                              EIGHT MEN  FOUR WOMEN        0.766667
# 16335                                   HEARTBREAK HOTEL        0.500000
# 16354                                   WHOS MAKING LOVE        0.428571
# 16442                        WEDDING SONG  THERE IS LOVE        0.700000
# 16951                                            DO I DO        0.000000
# 17026                                            SAY MAN        0.000000
# 17032                                            BECAUSE        0.631579
# 17071              ILL TAKE YOU WHERE THE MUSICS PLAYING        0.000000
# 17075                               ITS A MAN DOWN THERE        0.437500
# 17126                             DONT LET ME CROSS OVER        0.666667
# 17141                                         7 AND 7 IS        0.000000
# 17204                                        YOU YOU YOU        0.000000
# 17690                                       BED OF ROSES        0.695122
# 17768               MAN SIZE LOVE  FROM "RUNNING SCARED"        0.000000
# 17876                                   WHOLE LOTTA LOVE        0.431818
# 17877                                       BIGGER > YOU        0.680000
# 18359                                 WELCOME TO JAMROCK        0.434783
# 18438                                 PICK UP THE PIECES        0.687500
# 18523                           SHOOT ME  WITH YOUR LOVE        0.000000
# 18561                                    I NEED SOMEBODY        0.444444
# 18595                                            THE MAN        0.000000
# 18627                            THE KEEPER OF THE STARS        0.000000
# 18816                                   NEW MEXICAN ROSE        0.573529
# 18837                                 THATS THE ONLY WAY        0.573529
# 18858                                     SMALL PARADISE        0.566667
# 18891                                           THE DAYS        0.000000
# 19035                               TAKE ANOTHER PICTURE        0.000000
# 19063                                           RAMBLING        0.423077
# 19208                                   TO LOVE SOMEBODY        0.000000
# 19276                           ALL ALONG THE WATCHTOWER        0.648148
# 19448                                      PURPLE MEDLEY        0.607143
# 19527                       CANT GET ENOUGH OF YOU  BABY        0.444444
# 19532                                TEARS  TEARS  TEARS        0.000000
# 19608                                        LOVEY DOVEY        0.517241
# 19631                                        GOIN CRAZY!        0.000000
# 19680                              ILL TRY SOMETHING NEW        0.500000
# 19706                        IM LIKE A LAWYER ME AND YOU        0.000000
# 19721                            SPEND THE NIGHT IN LOVE        0.573529
# 19737                                THE PICK OF DESTINY        0.000000
# 19828                                  QUEEN OF MY HEART        0.620457
# 19831                         THE GREEN LEAVES OF SUMMER        0.000000
# 19963                                           SPOONFUL        0.500000
# 20128                            AINT GOT NO; I GOT LIFE        0.000000
# 20135                                      RED EYE BLUES        0.866667
# 20260                                             NO ONE        0.666667
# 20485          YOUVE NEVER BEEN IN LOVE LIKE THIS BEFORE        0.583333
# 20539                           WHERE ARE YOU CHRISTMAS?        0.766667
# 20649                      BIT BY BIT  THEME FROM FLETCH        0.000000
# 20711                 I LOVE YOU  I LOVE YOU  I LOVE YOU        0.000000
# 20726                                      ABOUT YOU NOW        0.687500
# 20866                                   BABY  BABY  BABY        0.000000
# 21001                                  WELCOME 2 DETROIT        0.500000
# 21103                                     WHO IS SHE 2 U        0.000000
# 21177                                          SINCERELY        0.573529
# 21194                                      I TOLD YOU SO        0.500000
# 21318                                            IN TIME        0.450000
# 21534                                   HOLDING MY HEART        0.800000
# 21557                                I RECEIVED A LETTER        0.470588
# 21592                             GIRL  YOU CAPTIVATE ME        0.444444
# 21711                                            SHADOWS        0.566667
# 21771                                   JANE  JANE  JANE        0.000000
# 21773                     DONT EVER TAKE AWAY MY FREEDOM        0.625000
# 21823                         WALLS  FROM "SHES THE ONE"        0.000000
# 21861                                       FUNKY DONKEY        0.478261
# 21924                                    LOVES ONLY LOVE        0.476190
# 22014                                      DEVILS ANGELS        0.788462
# 22158                                          TOO DRUNK        0.666667
#
#        twogram_title
# 159         0.631579
# 306         0.591837
# 334         0.800000
# 361         0.466667
# 553         0.692308
# 583         0.509434
# 704         0.433333
# 751         0.000000
# 760         0.000000
# 765         0.000000
# 896         0.863636
# 1114        0.575269
# 1168        0.455556
# 1400        0.671587
# 1450        0.646341
# 1555        0.680851
# 1558        0.555556
# 1591        0.520548
# 1818        0.000000
# 1821        0.473684
# 1827        0.681818
# 1860        0.000000
# 1942        0.000000
# 2026        0.000000
# 2037        0.000000
# 2156        0.509259
# 2196        0.511628
# 2213        0.000000
# 2231        0.673913
# 2472        0.433333
# 2514        0.300000
# 2530        0.535714
# 2563        0.000000
# 2634        0.482353
# 3359        0.609756
# 3434        0.477273
# 3692        0.581081
# 3738        0.400000
# 3987        0.000000
# 4077        0.482759
# 4099        0.000000
# 4127        0.635135
# 4387        0.460000
# 4501        0.642857
# 4587        0.596774
# 5013        0.765625
# 5019        0.533333
# 5033        0.000000
# 5044        0.437500
# 5072        0.605263
# 5153        0.050000
# 5255        0.620253
# 5309        0.525000
# 5326        0.652174
# 5447        0.000000
# 5449        0.625000
# 5454        0.000000
# 5470        0.673913
# 5496        0.463768
# 5669        0.590909
# 5936        0.000000
# 6036        0.463636
# 6110        0.541667
# 6143        0.674419
# 6292        0.593220
# 6714        0.466667
# 6944        0.581081
# 7019        0.000000
# 7023        0.000000
# 7034        0.700000
# 7073        0.000000
# 7230        0.464286
# 7830        0.700000
# 7889        0.000000
# 7899        0.473214
# 8077        0.650943
# 8086        0.000000
# 8176        0.573864
# 8236        0.000000
# 8398        0.000000
# 8923        0.500000
# 8931        0.642857
# 8948        0.000000
# 9309        0.621212
# 9441        0.000000
# 9559        0.000000
# 9580        0.617188
# 9637        0.483871
# 9653        0.500000
# 9668        0.000000
# 9710        0.888889
# 9721        0.270492
# 9805        0.691176
# 9901        0.440476
# 10011       0.298246
# 10067       0.214286
# 10095       0.448276
# 10154       0.000000
# 10217       0.625000
# 10378       0.552632
# 10407       0.000000
# 10443       0.000000
# 10463       0.552632
# 10492       0.000000
# 10556       0.438776
# 10619       0.000000
# 10623       0.764706
# 10684       0.687500
# 10823       0.446429
# 10862       0.666667
# 10997       0.645833
# 11409       0.000000
# 11617       0.846154
# 11622       0.554545
# 11660       0.600000
# 11741       0.615385
# 11962       0.538462
# 12049       0.696429
# 12062       0.000000
# 12150       0.687500
# 12655       0.620000
# 12836       0.676471
# 13006       0.687500
# 13124       0.455556
# 13147       0.000000
# 13225       0.687500
# 13510       0.519231
# 13716       0.600000
# 13796       0.444444
# 13841       0.000000
# 13925       0.630000
# 13935       0.500000
# 14000       0.640625
# 14121       0.581395
# 14133       0.509804
# 14260       0.000000
# 14372       0.000000
# 14431       0.480000
# 14664       0.814815
# 14671       0.685185
# 14689       0.500000
# 14696       0.492308
# 14725       0.663462
# 14997       0.653846
# 15008       0.000000
# 15045       0.000000
# 15086       0.484375
# 15106       0.660000
# 15258       0.632353
# 15333       0.000000
# 15474       0.462121
# 15853       0.583333
# 15944       0.500000
# 16018       0.521739
# 16079       0.592105
# 16090       0.563063
# 16097       0.000000
# 16107       0.466102
# 16113       0.486486
# 16126       0.543478
# 16280       0.636986
# 16289       0.000000
# 16295       0.520833
# 16300       0.500000
# 16335       0.421053
# 16354       0.138889
# 16442       0.448980
# 16951       0.437500
# 17026       0.500000
# 17032       0.666667
# 17071       0.648649
# 17075       0.000000
# 17126       0.000000
# 17141       0.681818
# 17204       0.694444
# 17690       0.000000
# 17768       0.520000
# 17876       0.452381
# 17877       0.608108
# 18359       0.000000
# 18438       0.000000
# 18523       0.439024
# 18561       0.000000
# 18595       0.631579
# 18627       0.560606
# 18816       0.000000
# 18837       0.000000
# 18858       0.000000
# 18891       0.500000
# 19035       0.575000
# 19063       0.333333
# 19208       0.437500
# 19276       0.469388
# 19448       0.715909
# 19527       0.000000
# 19532       0.605263
# 19608       0.000000
# 19631       0.462963
# 19680       0.000000
# 19706       0.493151
# 19721       0.233333
# 19737       0.684211
# 19828       0.617647
# 19831       0.650376
# 19963       0.600000
# 20128       0.587838
# 20135       0.566667
# 20260       0.750000
# 20485       0.841463
# 20539       0.512048
# 20649       0.457627
# 20711       0.602941
# 20726       0.000000
# 20866       0.650000
# 21001       0.483871
# 21103       0.531250
# 21177       0.000000
# 21194       0.000000
# 21318       0.644737
# 21534       0.500000
# 21557       0.430556
# 21592       0.000000
# 21711       0.000000
# 21771       0.656250
# 21773       0.000000
# 21823       0.692308
# 21861       0.000000
# 21924       0.500000
# 22014       0.529412
# 22158       0.615385

# %%
# Manually verify and create a list of 
try:
    # List of iterators that are verified 
    verified_iterators = ['2FhwclPOq1BFSodmaseNRX','1IYn7ytdb8byvHKS7S3Cat','67eX1ovaHyVPUinMHeUtIM','43btz2xjMKpcmjkuRsvxyg','0Of5lCNEqh62twRkQIOLuK','7FtORS5qspEVqRGLTgLYwv','4dASQiO1Eoo3RJvt74FtXB','3GrH2iOYpYAqfzFPAi0ZUI','130osY0woeFCu77M4cBniA','234pZV6o8NoJoEnW56q8u9','0fXd3B3PbDr1fQvgZ2ZLfV','7fPXqb7yuGbSl0ZM3EddHx','5Z5ZfEUCDN7lGrobPwXHLJ','1ngH7sRyID6dr51y6K8AmF','375ntCG12wzCyfzclwYFwG','6LpYKfPDviJJDWNDOrtnoA','0vFmCEzqAW5aXFTrGlR7j8','2VZzXJX14IZOmdXN2MuH9j','6lSVidZXCnOnYAWcgIqVDF','3cf5jnygf67JWEBBCbsg0F','1XkVDfAdPpjFLCGWaWmF4D','0XOuVAHsANAWw0LF0Yxkw5','1mzAgAg2Bd4AMwphrbIIMv','3lsse1FoSHnNXc6y0jHxvd','3o8ls4KmiVYMymyiHuZtSi','4z8D58IC56O0JH2B818SkX','4qv7YSyt5UV8LvrXyE8sGn','4kik1yiPf2UJ4qd991qnwK','4oy4gZOLCTwMh2FjNo5RQJ','5Gei3XPSL1AWAntiZ6TgXD','7xG1fakElLbxwyr9eyGEK6','4lJNen4SMTIJMahALc3DcB','51nRQic7PFMD4NsdRj6soX','2NkDQv8y2DkoYQURdiZCOk','6Ui2yvA0D5bXxZiPFWd47y','00meczE1jpLTX0BBzIGrAR','0NpvdCO506uO58D4AbKzki','2aIXrAbyO9HvrlWGWfpfKa','2Du6IbzikdqDOSYLJQwT12','18ocy9Be9SxWEEnOLGDfkS','2n57bbhDsRMvUdUtuqIYxN','2tux0ui8n2qdHdGpBnkhol','1Ds4fOZtxhUh9N9pOVbALx','4XRkQloZFcRrCONN7ZQ49Y','04CpLajxMkVmvNyRtmwlvg','5LjSxAIKwyZvQqJ04ZQ0Da','0Cwn4fq9ysV0PsfSew34bp','2iIeQdi360dvjmjDWrvryp','5Sx26i9lDxDHTOM5YvxVOt','0loo1QzCmSXerjeZBUVLPG','4TlHAudhkMzNoj19RuzGr0','00U0pedRUMEzREpyRqbVT6','4C76SOnBa9eQDwOwe11hPz','6doSV1UQjyKxiNCnBnDTeG','0BsmelqdNWE1KBxNL5NIYF','1ZVgydICDwNpd9OMVbaAU0','0K3i1MJwU4v0Aq0VdYZnPg','76PjPbGl8IaVqJWV153oJn','1v4ROufvjD8wEkfdyg3Yk1','7nVQ8mo77KaUvhUQzh4vMy','1y0ZoHeeEd0XTT8X7SnSq3','221899EK6HGwW9xBc8sfCq','3D97kRhZprR6RumFhDFIr4','51rXHuKN8Loc4sUlKPODgH','15YtixaZ1VgE3fPfXahlzD','10MhX3LZPs8VYMCfJnUOUe','5tSJcd6jMcFCyKnI5JTag4','18vT0ddyQSJTdQPGRpM0en','2X51AKflJTB6IVPwrbMtMS','1deYpfv1m5w1TmGz9xyKAn','2g8OuYXyWjNbLyVjFRGWDg','2Oot9guaaxLj7o4vBjW1SV','4yjYZQpjpeSBzIMFM5NVV6','2cdwkBvcf927tAUvCR2ggy','3klgM4azrZNgZ0bsZ7G5I2','14zpTN39s1y9Mb0RrXiSFC','38SctZyQGZqE2yC9fNdzyD','3RxF3Mz5wprRMopI8fp9uF','1ePIjPuiQvrLKKYJhW7dPh','4AFLFG6pyvhBLC37FbDwc2','1WvcgDbT79xeAa7Mv0klkK','7bdlmyOAMwUwLmE85K8mN2','6Pzbv8zwmq31mq998fBG5i','2gFfG8Ick2LGOzFHiWOV22','4vsJejr0UiQDppgqDlQVZe','4vxOl0RGNzW05Dp6zyvUo0','2BU4dK1fu1CFLjTBz7ju7Q','1CHDQPobVEBX2vsvhAxNBM','4mLbbnDWp5NoJXP0WxjcmA','5zmwXfoHO0s9WHN0k2Ntcu','4elVuCOp5pp4yzobTO5thA','3TyhfD8fjfkzg9ujAM9qPO','6Qu1yi6M7Z0BoH39bSiBfu','5S1IUPueD0xE0vj4zU3nSf','22AbXxQbMdVqEz7xJjhccG','2x1LQq8lsUzAA2wNj8yjC9','0XXnQWgIdaUsp2twWmqmU3','5BSlukklfUTrmzmsuctmMr','0NYARSjTaMT67cbW3JozJI','15B1limEYsrV2tKWeUjAnS','66nWGFaJUCa5MDlaMPmcRR','1jRnSVA3PfS0BhoKylM4E2','5dZiQVyXv66lYP2SSm8Ne1','4bsCuHdTpVqf90EJ7oowMX','6A9nyMBdNUzVcFHZUEZ71F','4wwLIS4ONohVyhVb5zCPOH','2370aszHFScynGrF9tN7lC','5VgcM58bybW45T2WgTdbeY','1msuiw6pnXYfxZ7Edyit9U','53435bte8yCZDBipvsq7cm','3oRMeMMJ1xUhBBpy2iGE2g','0ElQWopuhQ10wgGouWSVlR','5jSAfX8SJVD5uzFyLlTVwo','5xS3g1B4lSplD8F8Rt2XzF','7zI8PUaeTfj2kgmqHnyIO8','3woGPx9i3RByafS2lWKGVP','0slyXInD5PEFYidY4pgZhC','3JeN8VELWzS0j91jddgsYb','36KNwRx1fpLhHthtq4W9ym','39LSfgIQHJwKi3gBDXmcwi']
    hot100_ids.loc[hot100_ids['iterator'].isin(verified_iterators),'verified'] = True
except:
    print('already updated')
    
# Remove remaining
cond_is_null = hot100_ids['verified'].isnull()
cond_not_verified = hot100_ids['verified'] == False

hot100_ids.loc[cond_is_null,['iterator','spotify_artist','spotify_title']] = np.nan
hot100_ids.loc[cond_not_verified,['iterator','spotify_artist','spotify_title']] = np.nan

# %%
# The same title with slight variations
hot100_ids.loc[hot100_ids.duplicated(subset=['artist','title'],keep=False),['artist','title']].sort_values(by=['artist','title']).head()
# Out:
#                            artist             title
# 6088            Alanis Morissette       Hands Clean
# 18052           Alanis Morissette       Hands Clean
# 16197  April Stevens & Nino Tempo  Sweet And Lovely
# 18072  April Stevens & Nino Tempo  Sweet And Lovely
# 14388    Archie Bell & The Drells        Wrap It Up

# %% [markdown]
# The scraped spotify ids include a few title and artist combinations that reference the same entity, to avoid duplications on a merge those duplicates will be removed and only the last is kept.

# %%
# Remove verification for songs that are the same with slightly different versions based on twogram
cond_verified_duplicates = (hot100_ids.duplicated(subset=['artist','title'],keep='last')) & (hot100_ids['verified'] == True)
hot100_ids.loc[cond_verified_duplicates,'verified'] = False

# %%
# Create verified hot100 ids
cond_is_verified = hot100_ids['verified'] == True
hot100_ids_verified = hot100_ids.loc[cond_is_verified,:].copy()

# Sanity Check
print("Verified: {}\nNot Verified: {}\nUnknown: {}".format(len(hot100_ids_verified[hot100_ids_verified['verified'] == True]),len(hot100_ids_verified[hot100_ids_verified['verified'] == False]),(len(hot100_ids_verified[hot100_ids_verified['verified'].isnull()]))))
# Out:
# Verified: 21002
# Not Verified: 0
# Unknown: 0

# %% [markdown]
# At last we're left with 21002 unique songs that are verfied.

# %%
# Merge hot100 and ids + Sanity Check
hot100_w_ids = hot100_all.merge(hot100_ids_verified,how='left',on=['artist','title'])
print("Length of all hot100_all and merged hot100_w_ids match: {} ({})".format(len(hot100_w_ids) == len(hot100_all),len(hot100_w_ids)))

# Create Iterator for Hot100 Spotify Ids (make sure to run make_spotify_features.py)
hot100_iterators = hot100_w_ids['iterator'].drop_duplicates().dropna()
hot100_iterators.to_csv('../iterators/spotify_ids_iterator.csv',header=['iterator'],sep='\t',index=False,encoding='utf-8')
# Out:
# Length of all hot100_all and merged hot100_w_ids match: True (316685)

# %% [markdown]
# We'll now go on to combine these verfied songs with the song analysis datasets pulled from the spotify API ([features endpoint](https://developer.spotify.com/documentation/web-api/reference/tracks/get-several-audio-features/)).

# %%
# Read in all Subfiles
filenames = glob('spotify_analysis_api/*.csv')
hot100_analysis_dfs = [pd.read_csv(filepath,sep='\t') for filepath in filenames]
hot100_analysis_all = pd.concat(hot100_analysis_dfs)

# %%
# Prepare analysis objects and drop duplicates
hot100_analysis_matched = hot100_analysis_all.loc[hot100_analysis_all.name.isin(hot100_ids_verified.iterator),:]
print(len(hot100_analysis_matched))
hot100_analysis_matched.head()
# Out:
# 21002
#                      name  danceability  energy  key  loudness  mode  \
# 0  6Vfiskl8VZSui0ggqd5Mfg         0.396   0.584    5    -5.568     1
# 1  46ShsS3tyqJAJdxUjPezdI         0.627   0.467    9    -9.810     1
# 2  15birTLhbfY95FUejmYSv7         0.436   0.117    4   -14.170     1
# 3  1zGurRysA9yFI5qa7gaR8O         0.798   0.801    1    -5.858     1
# 4  01PnRJeFSeOgIpBuv1kQKd         0.710   0.665    2    -7.632     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0339       0.80200          0.000002     0.133   0.3380  120.461
# 1       0.0321       0.00286          0.000000     0.110   0.6100  113.010
# 2       0.0309       0.90700          0.000025     0.083   0.0988  130.290
# 3       0.1390       0.07730          0.000384     0.200   0.6670  107.516
# 4       0.0277       0.05300          0.020700     0.177   0.7960  127.472
#
#              type                      id  \
# 0  audio_features  6Vfiskl8VZSui0ggqd5Mfg
# 1  audio_features  46ShsS3tyqJAJdxUjPezdI
# 2  audio_features  15birTLhbfY95FUejmYSv7
# 3  audio_features  1zGurRysA9yFI5qa7gaR8O
# 4  audio_features  01PnRJeFSeOgIpBuv1kQKd
#
#                                     uri  \
# 0  spotify:track:6Vfiskl8VZSui0ggqd5Mfg
# 1  spotify:track:46ShsS3tyqJAJdxUjPezdI
# 2  spotify:track:15birTLhbfY95FUejmYSv7
# 3  spotify:track:1zGurRysA9yFI5qa7gaR8O
# 4  spotify:track:01PnRJeFSeOgIpBuv1kQKd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6Vfiskl8VZSu...
# 1  https://api.spotify.com/v1/tracks/46ShsS3tyqJA...
# 2  https://api.spotify.com/v1/tracks/15birTLhbfY9...
# 3  https://api.spotify.com/v1/tracks/1zGurRysA9yF...
# 4  https://api.spotify.com/v1/tracks/01PnRJeFSeOg...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6Vfi...       615093
# 1  https://api.spotify.com/v1/audio-analysis/46Sh...       240613
# 2  https://api.spotify.com/v1/audio-analysis/15bi...       184320
# 3  https://api.spotify.com/v1/audio-analysis/1zGu...       291493
# 4  https://api.spotify.com/v1/audio-analysis/01Pn...       164293
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
hot100_processed = hot100_w_ids.merge(hot100_analysis_matched,left_on=['iterator'],right_on=['id'],how='left')
print("Length of all hot100_all and merged hot100_processed match: {} ({})".format(len(hot100_processed) == len(hot100_all),len(hot100_processed)))
# Out:
# Length of all hot100_all and merged hot100_processed match: True (316685)

# %%
processed_path = '../processed/'
hot100_target = 'hot100_processed.csv'
hot100_processed.to_csv(processed_path + hot100_target,sep='\t',index=False,encoding='utf-8')
hot100_processed.head()
# Out:
#    rank       date                                              title  \
# 0     1 1967-07-08                                              Windy
# 1     2 1967-07-08                                 Little Bit O' Soul
# 2     3 1967-07-08                         Can't Take My Eyes Off You
# 3     4 1967-07-08  San Francisco (Be Sure To Wear Flowers In Your...
# 4     5 1967-07-08                          Don't Sleep In The Subway
#
#                 artist                iterator  \
# 0      The Association  6RUpOheT93fUdI508K5w6U
# 1  The Music Explosion  75obkRHfYSwnd20wXMreRO
# 2        Frankie Valli                     NaN
# 3       Scott McKenzie  77qBwefBIdzymXNCuAI8YX
# 4         Petula Clark  1ljijVo7rDHSuXIhydPpNl
#
#                                       filename       spotify_artist  \
# 0  ./data/interim/hot100/hot100_1967-07-03.csv      THE ASSOCIATION
# 1  ./data/interim/hot100/hot100_1967-07-03.csv  THE MUSIC EXPLOSION
# 2                                          NaN                  NaN
# 3  ./data/interim/hot100/hot100_1967-07-03.csv       SCOTT MCKENZIE
# 4  ./data/interim/hot100/hot100_1967-07-03.csv         PETULA CLARK
#
#                                        spotify_title verified  \
# 0                                              WINDY     True
# 1                     LITTLE BIT O SOUL   ACTION MIX     True
# 2                                                NaN      NaN
# 3  SAN FRANCISCO  BE SURE TO WEAR SOME FLOWERS IN...     True
# 4                           DONT SLEEP IN THE SUBWAY     True
#
#            orig_artist  ... liveness  valence    tempo            type  \
# 0      THE ASSOCIATION  ...    0.105    0.898  132.996  audio_features
# 1  THE MUSIC EXPLOSION  ...    0.313    0.889  136.459  audio_features
# 2                  NaN  ...      NaN      NaN      NaN             NaN
# 3       SCOTT MCKENZIE  ...    0.219    0.478  112.443  audio_features
# 4         PETULA CLARK  ...    0.167    0.427  133.685  audio_features
#
#                        id                                   uri  \
# 0  6RUpOheT93fUdI508K5w6U  spotify:track:6RUpOheT93fUdI508K5w6U
# 1  75obkRHfYSwnd20wXMreRO  spotify:track:75obkRHfYSwnd20wXMreRO
# 2                     NaN                                   NaN
# 3  77qBwefBIdzymXNCuAI8YX  spotify:track:77qBwefBIdzymXNCuAI8YX
# 4  1ljijVo7rDHSuXIhydPpNl  spotify:track:1ljijVo7rDHSuXIhydPpNl
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6RUpOheT93fU...
# 1  https://api.spotify.com/v1/tracks/75obkRHfYSwn...
# 2                                                NaN
# 3  https://api.spotify.com/v1/tracks/77qBwefBIdzy...
# 4  https://api.spotify.com/v1/tracks/1ljijVo7rDHS...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6RUp...     174600.0
# 1  https://api.spotify.com/v1/audio-analysis/75ob...     141827.0
# 2                                                NaN          NaN
# 3  https://api.spotify.com/v1/audio-analysis/77qB...     178933.0
# 4  https://api.spotify.com/v1/audio-analysis/1lji...     175373.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             NaN
# 3             4.0
# 4             4.0
#
# [5 rows x 32 columns]

# %%
hot100_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316685 entries, 0 to 316684
# Data columns (total 32 columns):
# rank                316685 non-null int64
# date                316685 non-null datetime64[ns]
# title               316685 non-null object
# artist              316685 non-null object
# iterator            246311 non-null object
# filename            246311 non-null object
# spotify_artist      246311 non-null object
# spotify_title       246311 non-null object
# verified            246311 non-null object
# orig_artist         246311 non-null object
# orig_title          246311 non-null object
# twogram_artist      246311 non-null float64
# twogram_title       246311 non-null float64
# name                246311 non-null object
# danceability        246311 non-null float64
# energy              246311 non-null float64
# key                 246311 non-null float64
# loudness            246311 non-null float64
# mode                246311 non-null float64
# speechiness         246311 non-null float64
# acousticness        246311 non-null float64
# instrumentalness    246311 non-null float64
# liveness            246311 non-null float64
# valence             246311 non-null float64
# tempo               246311 non-null float64
# type                246311 non-null object
# id                  246311 non-null object
# uri                 246311 non-null object
# track_href          246311 non-null object
# analysis_url        246311 non-null object
# duration_ms         246311 non-null float64
# time_signature      246311 non-null float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(15)
# memory usage: 79.7+ MB

# %%
hot100_processed.drop_duplicates(subset=['artist','title']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28083 entries, 0 to 316674
# Data columns (total 32 columns):
# rank                28083 non-null int64
# date                28083 non-null datetime64[ns]
# title               28083 non-null object
# artist              28083 non-null object
# iterator            21002 non-null object
# filename            21002 non-null object
# spotify_artist      21002 non-null object
# spotify_title       21002 non-null object
# verified            21002 non-null object
# orig_artist         21002 non-null object
# orig_title          21002 non-null object
# twogram_artist      21002 non-null float64
# twogram_title       21002 non-null float64
# name                21002 non-null object
# danceability        21002 non-null float64
# energy              21002 non-null float64
# key                 21002 non-null float64
# loudness            21002 non-null float64
# mode                21002 non-null float64
# speechiness         21002 non-null float64
# acousticness        21002 non-null float64
# instrumentalness    21002 non-null float64
# liveness            21002 non-null float64
# valence             21002 non-null float64
# tempo               21002 non-null float64
# type                21002 non-null object
# id                  21002 non-null object
# uri                 21002 non-null object
# track_href          21002 non-null object
# analysis_url        21002 non-null object
# duration_ms         21002 non-null float64
# time_signature      21002 non-null float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(15)
# memory usage: 7.1+ MB

# %%
hot100_date = hot100_processed.set_index('date')
hot100_date['year'] = hot100_date.index.year
by_year = hot100_date.groupby(by='year').count().loc[:,['rank','iterator']]
by_year.columns = ['total','complete']
by_year['missing'] = by_year['total'] - by_year['complete']


fig = plt.figure(figsize=(16,6))
x = by_year.index
y = by_year.missing
y_all = by_year.total
_ = plt.bar(x,y_all,color='gray',alpha=0.5,label='total')
_ = plt.bar(x,y,color='orange',label='missing')
_ = plt.title('Missing Values by Year')
_ = plt.xlabel('Year')
_ = plt.ylabel('Number of Songs')
_ = plt.legend()

# %% [markdown]
# Most missing values are in the late 90's and 2018 as well as all the way back in 1958. The late 80's and early 90's show the least amount of missing values but generally the number of missing songs for a year are around 1/5th of all data, for the periods with higher missing values this number can get close to 2/5th.
#
# There are two obvious years that would show incomplete data (e.g. 1958 - the first year - and 2019 - the current year -). Beyond those two years we can see that some years have more than 5200 entries (i.e. 5300 entries). This is due to the fact that the Billboard Hot 100 are released on a Saturday and every so often there are 53 Saturdays in a year (i.e. 1966, 1972, 1977, 1983, etc.).
#
# Lastly, there is slight dip in the years 1976 and 1977 (almost not visible). This is due to missing data on the Billboard Hot 100 charts in the period between 1976-11-22 and 1977-02-28. In this 15 week period exactly one rank/position is missing each week (i.e. 99 songs are on the charts each week for this period). Since this is a minor issue it likely won't affect our model.

# %% [markdown]
# In the following we'll check for consistency by rank.

# %%
hot100_rank = hot100_processed.set_index('rank')
by_rank = hot100_rank.groupby(by='rank').count().loc[:,['title','iterator']]
by_rank.columns = ['total','complete']
by_rank['missing'] = by_rank['total'] - by_rank['complete']


fig = plt.figure(figsize=(16,6))
x = by_rank.index
y = by_rank.missing
y_all = by_rank.total
_ = plt.bar(x,y_all,color='gray',alpha=0.5,label='total')
_ = plt.bar(x,y,color='orange',label='missing')
_ = plt.title('Missing Values by Rank')
_ = plt.xlabel('Rank')
_ = plt.ylabel('Number of Songs')
_ = plt.legend()

# %% [markdown]
# There is no clear trend as to missing values by rank/position. Missing values occur just as often for higher ranks as for lower ranks in our Billboard Hot 100 Charts set. If any trend is visible there might be slightly more missing values towards the lower ranks (toward 100) then in the higher positions, but this trend seems negligible.
#
# Next we'll see how missing values are distributed among unique songs. Since we're dropping the duplicates but a song can enter and leave at different positions in the Hot 100 chart we'll create a new position identifier that tracks the highest achieved positions (i.e. peak position).

# %%
peak_ranks = hot100_all.groupby(['title','artist']).min().loc[:,'rank']
peak_ranks = peak_ranks.rename('peak')
hot100_processed = hot100_processed.merge(peak_ranks,how='left',on=['title','artist'])

hot100_uniq = hot100_processed.drop_duplicates(subset=['artist','title'],keep='first')
hot100_uniq = hot100_uniq.set_index('date')
hot100_uniq['year'] = hot100_uniq.index.year
by_year_uniq = hot100_uniq.groupby(by='year').count().loc[:,['rank','iterator']]
by_year_uniq.columns = ['total','complete']
by_year_uniq['missing'] = by_year_uniq['total'] - by_year_uniq['complete']
# Add a proportion column
by_year_uniq['ratio'] = by_year_uniq['complete'] / by_year_uniq['total']

fig = plt.figure(figsize=(16,6))
x = by_year_uniq.index
y = by_year_uniq.missing
y_ratio = by_year_uniq.ratio
y_all = by_year_uniq.total
_ = plt.bar(x,y_all,color='gray',alpha=0.5, label='total')
_ = plt.bar(x,y,color='orange', label='missing')
_ = plt.title('Missing Values by Year')
_ = plt.xlabel('Year')
_ = plt.ylabel('Number of Songs')

_ = plt.legend(loc='upper left')

_ = plt.twinx()
_ = plt.plot(x,y_ratio,color='black')
_ = plt.yticks(np.arange(0,1.2,0.2))
_ = plt.grid(False)

_ = plt.legend(loc='upper right')

# %% [markdown]
# Looking at the unique songs, likely the more important metric for our model, we can see that the lower number of missing values in the late 1980s to late 1990s coincides with a lower number of unique songs in the charts by year. This is due to the fact that there is less total fluctuation in the Billboard Hot 100 Charts through time (i.e. songs remain in the charts relatively longer) compared to the 1960s and early 1970s.
#
# That being said we've seen a stagnation of this trend over the past decade with an uptick in recent years (especially 2018).
#
# The overall ratio of complete unique songs to total unique songs ranges between .6 and .9.

# %%
np.arange(0,1,0.2)
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8])
